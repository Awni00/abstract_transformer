# %%
import torch
import torchinfo
import numpy as np
import math
import os
import time
from contextlib import nullcontext

import sys; sys.path.append('..')
from models import TransformerLM, AbstractTransformerLM, configure_optimizers
from train_utils import train_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       7 from contextlib import nullcontext
#       9 import sys; sys.path.append('..')
# ---> 10 from models import TransformerLM, AbstractTransformerLM, configure_optimizers
#      11 from train_utils import train_model
#
# ModuleNotFoundError: No module named 'models'

# %%
print('cuda available: ', torch.cuda.is_available())
print('device count: ', torch.cuda.device_count())
print('current device name: ', torch.cuda.get_device_name(torch.cuda.current_device()))
print('Memory Usage:')
print('\tAllocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
print('\tReserved:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# cuda available:  True
# device count:  1
# current device name:  NVIDIA A100-PCIE-40GB
# Memory Usage:
# 	Allocated: 0.0 GB
# 	Reserved:    0.0 GB

# %% [markdown]
# ## Config

# %%
data_path = f'../data/tiny_shakespeare_char'

# I/O
eval_only = False # if True, script exits right after the first eval

# system
device = 'cuda'
device_type = 'cuda' if 'cuda' in device else 'cpu' # for later use in torch.autocast

# 'float32', 'bfloat16', or 'float16', the latter will auto implement a GradScaler
dtype = 'bfloat16' if torch.cuda.is_available() and torch.cuda.is_bf16_supported() else 'float16' 
compile = True

# evaluation and output
out_dir = '../out/out-shakespeare-char'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
eval_interval = 250 # keep frequent because we'll overfit
eval_iters = 200
log_interval = 10 # don't print too too often

# we expect to overfit on this small dataset, so only save when val improves
always_save_checkpoint = False

# wandb logging
wandb_log = False
wandb_project = 'abstract_transformer--shakespeare_char'
wandb_run_name = 'mini-gpt'

# optimization hyperparams
learning_rate = 1e-3 # with baby networks can afford to go a bit higher
max_iters = 5000
grad_clip = 1.0 # clip gradients at this value, or disable if == 0.0
decay_lr = True # whether to decay the learning rate
lr_decay_iters = 5000 # make equal to max_iters usually
weight_decay = 1e-1
min_lr = 1e-4 # learning_rate / 10 usually
beta1 = 0.9
beta2 = 0.99 # make a bit bigger because number of tokens per iter is small
warmup_iters = 100
gradient_accumulation_steps = 1 # accumulate gradients over this many steps. simulates larger batch size

# batch size and block size
batch_size = 64
block_size = 256

# DDP (distributed data parallel) training
ddp = False
master_process = True

# TODO: set up DDP for future experiments

# %%
ptdtype = {'float32': torch.float32, 'bfloat16': torch.bfloat16, 'float16': torch.float16}[dtype]
ctx = nullcontext() if device_type == 'cpu' else torch.amp.autocast(device_type=device_type, dtype=ptdtype)

# %% [markdown]
# ## Data Loader

# %%
# data loader
train_data = np.memmap(f'{data_path}_train.bin', dtype=np.uint16, mode='r')
val_data = np.memmap(f'{data_path}_val.bin', dtype=np.uint16, mode='r')
test_data = np.memmap(f'{data_path}_test.bin', dtype=np.uint16, mode='r')

def get_batch(split, batch_size=batch_size, block_size=256):
    data = train_data if split == 'train' else val_data if split == 'val' else test_data
    idx = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([torch.from_numpy((data[i:i+block_size]).astype(np.int64)) for i in idx])
    y = torch.stack([torch.from_numpy((data[i+1:i+1+block_size]).astype(np.int64)) for i in idx])
    if device == 'cuda':
        # pin arrays x,y, which allows us to move them to GPU asynchronously (non_blocking=True)
        x, y = x.pin_memory().to(device, non_blocking=True), y.pin_memory().to(device, non_blocking=True)
    else:
        x, y = x.to(device), y.to(device)
    return x, y
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # data loader
# ----> 2 train_data = np.memmap(f'{data_path}_train.bin', dtype=np.uint16, mode='r')
#       3 val_data = np.memmap(f'{data_path}_val.bin', dtype=np.uint16, mode='r')
#       4 test_data = np.memmap(f'{data_path}_test.bin', dtype=np.uint16, mode='r')
#
# File ~/.conda/envs/abstract_transformer/lib/python3.11/site-packages/numpy/core/memmap.py:229, in memmap.__new__(subtype, filename, dtype, mode, offset, shape, order)
#     227     f_ctx = nullcontext(filename)
#     228 else:
# --> 229     f_ctx = open(os_fspath(filename), ('r' if mode == 'c' else mode)+'b')
#     231 with f_ctx as fid:
#     232     fid.seek(0, 2)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/tiny_shakespeare_char_train.bin'

# %%
import pickle
meta_data = pickle.load(open(f'../data/shakespeare_char_meta.pkl', 'rb'))
vocab_size = meta_data['vocab_size']

# %% [markdown]
# ## Transformer Model

# %%
model_args = dict(
    vocab_size=vocab_size, d_model=384, n_layers=6, n_heads=6, dff=None,
    dropout_rate=0.2, activation='relu', norm_first=True, max_block_size=256, bias=True)
model = transformer_lm = TransformerLM(**model_args).to(device)

# %%
torchinfo.summary(model, input_data=torch.randint(0, 10, size=(1,256)), device='cuda')
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# TransformerLM                                 [1, 1, 65]                --
# ├─ModuleDict: 1-1                             --                        --
# │    └─Embedding: 2-1                         [1, 256, 384]             24,960
# │    └─Embedding: 2-2                         [256, 384]                98,304
# │    └─ModuleList: 2-3                        --                        --
# │    │    └─EncoderBlock: 3-1                 [1, 256, 384]             1,774,464
# │    │    └─EncoderBlock: 3-2                 [1, 256, 384]             1,774,464
# │    │    └─EncoderBlock: 3-3                 [1, 256, 384]             1,774,464
# │    │    └─EncoderBlock: 3-4                 [1, 256, 384]             1,774,464
# │    │    └─EncoderBlock: 3-5                 [1, 256, 384]             1,774,464
# │    │    └─EncoderBlock: 3-6                 [1, 256, 384]             1,774,464
# │    └─Linear: 2-4                            [1, 1, 65]                25,025
# ===============================================================================================
# Total params: 10,795,073
# Trainable params: 10,795,073
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 32.31
# ===============================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 34.60
# Params size (MB): 28.99
# Estimated Total Size (MB): 63.59
# ===============================================================================================

# %% [markdown]
# ### Training

# %%
scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16'))

# %%
# optimizer
optimizer = configure_optimizers(model, weight_decay, learning_rate, (beta1, beta2), device_type=device)
# Out:
# num decayed parameter tensors: 27, with 10,765,056 parameters
# num non-decayed parameter tensors: 49, with 30,017 parameters
# using fused AdamW: True

# %%
def get_lr(it):
    # 1) linear warmup for warmup_iters steps
    if it < warmup_iters:
        return learning_rate * it / warmup_iters
    # 2) if it > lr_decay_iters, return min learning rate
    if it > lr_decay_iters:
        return min_lr
    # 3) in between, use cosine decay down to min learning rate
    decay_ratio = (it - warmup_iters) / (lr_decay_iters - warmup_iters)
    assert 0 <= decay_ratio <= 1
    coeff = 0.5 * (1.0 + math.cos(math.pi * decay_ratio)) # coeff ranges 0..1
    return min_lr + coeff * (learning_rate - min_lr)

# %%
@torch.no_grad()
def eval_model(model, ctx=None):

    ctx = nullcontext() if ctx is None else ctx
    out = {}
    model.eval()
    for split in ['train', 'val', 'test']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            with ctx:
                logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[f'{split}/loss'] = losses.mean()
    model.train()
    return out

# %%
train_kwargs = dict(
    model=model, get_batch=get_batch, batch_size=batch_size, max_iters=max_iters,
    optimizer=optimizer, scaler=scaler, get_lr=get_lr, eval_model=eval_model,
    compile=True, grad_clip=0, gradient_accumulation_steps=gradient_accumulation_steps,
    eval_main_metric='val/loss', eval_interval=eval_interval, always_save_checkpoint=always_save_checkpoint, out_dir=out_dir,
    log_interval=10, wandb_log=True, wandb_init_kwargs=dict(project=wandb_project, name='TransformerLM'), 
    ckpt_dict=dict(model_args=model_args), track_mfu=True,
    master_process=True, ddp=False, device_type='cuda')

# %%
train_model(**train_kwargs)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: awni00. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.2
# Run data is saved locally in <code>/gpfs/gibbs/project/lafferty/ma2393/abstract_transformer/experiments/wandb/run-20240118_180608-yb0577xz</code>
# Syncing run <strong><a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/yb0577xz' target="_blank">TransformerLM</a></strong> to <a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char' target="_blank">https://wandb.ai/awni00/abstract_transformer--shakespeare_char</a>
#  View run at <a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/yb0577xz' target="_blank">https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/yb0577xz</a>
# compiling model... done compiling.
# starting training loop...
# step 0: train loss 4.4530, val loss 4.4662
# iter 0: loss 4.4761, time 55436.03ms, mfu -100.00%
# iter 10: loss 3.4657, time 28.53ms, mfu 13.12%
# iter 20: loss 3.0152, time 25.50ms, mfu 13.27%
# iter 30: loss 2.7761, time 25.39ms, mfu 13.42%
# iter 40: loss 2.6593, time 26.09ms, mfu 13.51%
# iter 50: loss 2.5758, time 25.43ms, mfu 13.63%
# iter 60: loss 2.5376, time 26.11ms, mfu 13.70%
# iter 70: loss 2.5154, time 25.29ms, mfu 13.81%
# iter 80: loss 2.5276, time 25.50ms, mfu 13.90%
# iter 90: loss 2.5017, time 25.33ms, mfu 13.98%
# iter 100: loss 2.4903, time 25.72ms, mfu 14.04%
# iter 110: loss 2.4787, time 25.36ms, mfu 14.11%
# iter 120: loss 2.4746, time 25.42ms, mfu 14.17%
# iter 130: loss 2.4568, time 31.65ms, mfu 13.94%
# iter 140: loss 2.4463, time 25.36ms, mfu 14.02%
# iter 150: loss 2.4175, time 25.34ms, mfu 14.09%
# iter 160: loss 2.3934, time 31.61ms, mfu 13.87%
# iter 170: loss 2.3491, time 25.60ms, mfu 13.94%
# iter 180: loss 2.3043, time 25.22ms, mfu 14.03%
# iter 190: loss 2.2711, time 25.27ms, mfu 14.11%
# iter 200: loss 2.1900, time 25.16ms, mfu 14.19%
# iter 210: loss 2.1625, time 25.23ms, mfu 14.25%
# iter 220: loss 2.1148, time 25.17ms, mfu 14.31%
# iter 230: loss 2.0897, time 25.17ms, mfu 14.37%
# iter 240: loss 2.0228, time 25.17ms, mfu 14.42%
# step 250: train loss 1.9470, val loss 2.0370
# saving checkpoint to ../out/out-shakespeare-char
# iter 250: loss 1.9967, time 6457.17ms, mfu 12.98%
# iter 260: loss 1.9771, time 25.42ms, mfu 13.16%
# iter 270: loss 1.9479, time 31.11ms, mfu 13.04%
# iter 280: loss 1.9328, time 25.25ms, mfu 13.22%
# iter 290: loss 1.9096, time 25.18ms, mfu 13.38%
# iter 300: loss 1.8866, time 25.24ms, mfu 13.53%
# iter 310: loss 1.8849, time 25.31ms, mfu 13.65%
# iter 320: loss 1.8284, time 25.27ms, mfu 13.77%
# iter 330: loss 1.8266, time 30.80ms, mfu 13.61%
# iter 340: loss 1.7858, time 25.17ms, mfu 13.73%
# iter 350: loss 1.7435, time 34.97ms, mfu 13.43%
# iter 360: loss 1.7559, time 25.09ms, mfu 13.58%
# iter 370: loss 1.7418, time 25.26ms, mfu 13.70%
# iter 380: loss 1.7086, time 25.16ms, mfu 13.82%
# iter 390: loss 1.7562, time 25.22ms, mfu 13.92%
# iter 400: loss 1.7035, time 26.60ms, mfu 13.94%
# iter 410: loss 1.6862, time 25.22ms, mfu 14.03%
# iter 420: loss 1.6686, time 26.05ms, mfu 14.06%
# iter 430: loss 1.6831, time 25.24ms, mfu 14.14%
# iter 440: loss 1.6657, time 33.54ms, mfu 13.84%
# iter 450: loss 1.6734, time 24.86ms, mfu 13.96%
# iter 460: loss 1.6505, time 24.96ms, mfu 14.06%
# iter 470: loss 1.6453, time 25.24ms, mfu 14.14%
# iter 480: loss 1.6112, time 25.32ms, mfu 14.20%
# iter 490: loss 1.5974, time 25.16ms, mfu 14.27%
# step 500: train loss 1.5485, val loss 1.7228
# saving checkpoint to ../out/out-shakespeare-char
# iter 500: loss 1.5990, time 6442.40ms, mfu 12.85%
# iter 510: loss 1.6162, time 25.04ms, mfu 13.06%
# iter 520: loss 1.6130, time 25.34ms, mfu 13.23%
# iter 530: loss 1.6060, time 25.11ms, mfu 13.40%
# iter 540: loss 1.6159, time 24.92ms, mfu 13.56%
# iter 550: loss 1.5742, time 30.80ms, mfu 13.42%
# iter 560: loss 1.5638, time 25.16ms, mfu 13.56%
# iter 570: loss 1.5925, time 25.02ms, mfu 13.70%
# iter 580: loss 1.5525, time 25.00ms, mfu 13.83%
# iter 590: loss 1.5740, time 25.11ms, mfu 13.94%
# iter 600: loss 1.5847, time 25.45ms, mfu 14.01%
# iter 610: loss 1.5279, time 24.96ms, mfu 14.11%
# iter 620: loss 1.5297, time 33.85ms, mfu 13.81%
# iter 630: loss 1.5261, time 25.23ms, mfu 13.91%
# iter 640: loss 1.5524, time 25.32ms, mfu 14.00%
# iter 650: loss 1.5816, time 25.30ms, mfu 14.08%
# iter 660: loss 1.5155, time 25.36ms, mfu 14.14%
# iter 670: loss 1.5420, time 25.82ms, mfu 14.18%
# iter 680: loss 1.5104, time 25.11ms, mfu 14.25%
# iter 690: loss 1.4708, time 25.15ms, mfu 14.31%
# iter 700: loss 1.4919, time 25.23ms, mfu 14.36%
# iter 710: loss 1.5263, time 25.35ms, mfu 14.40%
# iter 720: loss 1.4926, time 25.63ms, mfu 14.42%
# iter 730: loss 1.4965, time 25.24ms, mfu 14.46%
# iter 740: loss 1.4872, time 25.38ms, mfu 14.49%
# step 750: train loss 1.4045, val loss 1.5825
# saving checkpoint to ../out/out-shakespeare-char
# iter 750: loss 1.4499, time 6446.57ms, mfu 13.05%
# iter 760: loss 1.4574, time 25.04ms, mfu 13.24%
# iter 770: loss 1.4669, time 25.83ms, mfu 13.36%
# iter 780: loss 1.4742, time 32.57ms, mfu 13.17%
# iter 790: loss 1.4828, time 25.44ms, mfu 13.33%
# iter 800: loss 1.4779, time 25.25ms, mfu 13.48%
# iter 810: loss 1.4562, time 25.28ms, mfu 13.61%
# iter 820: loss 1.4448, time 25.15ms, mfu 13.74%
# iter 830: loss 1.4854, time 29.51ms, mfu 13.63%
# iter 840: loss 1.4594, time 25.19ms, mfu 13.75%
# iter 850: loss 1.4419, time 25.20ms, mfu 13.86%
# iter 860: loss 1.4458, time 25.37ms, mfu 13.95%
# iter 870: loss 1.4311, time 25.15ms, mfu 14.04%
# iter 880: loss 1.4062, time 25.11ms, mfu 14.13%
# iter 890: loss 1.4307, time 25.16ms, mfu 14.20%
# iter 900: loss 1.4401, time 25.15ms, mfu 14.27%
# iter 910: loss 1.4071, time 25.05ms, mfu 14.34%
# iter 920: loss 1.4078, time 25.12ms, mfu 14.39%
# iter 930: loss 1.4039, time 25.16ms, mfu 14.44%
# iter 940: loss 1.3958, time 25.41ms, mfu 14.47%
# iter 950: loss 1.3938, time 25.32ms, mfu 14.50%
# iter 960: loss 1.3931, time 34.90ms, mfu 14.12%
# iter 970: loss 1.4163, time 25.11ms, mfu 14.20%
# iter 980: loss 1.3941, time 25.11ms, mfu 14.27%
# iter 990: loss 1.3887, time 29.71ms, mfu 14.10%
# step 1000: train loss 1.3197, val loss 1.5342
# saving checkpoint to ../out/out-shakespeare-char
# iter 1000: loss 1.3743, time 6459.23ms, mfu 12.70%
# iter 1010: loss 1.3667, time 25.29ms, mfu 12.91%
# iter 1020: loss 1.3829, time 25.51ms, mfu 13.08%
# iter 1030: loss 1.4303, time 25.34ms, mfu 13.25%
# iter 1040: loss 1.3854, time 25.32ms, mfu 13.41%
# iter 1050: loss 1.4008, time 26.11ms, mfu 13.50%
# iter 1060: loss 1.3452, time 25.21ms, mfu 13.63%
# iter 1070: loss 1.3774, time 25.56ms, mfu 13.73%
# iter 1080: loss 1.3944, time 25.14ms, mfu 13.85%
# iter 1090: loss 1.3671, time 25.12ms, mfu 13.95%
# iter 1100: loss 1.3471, time 25.01ms, mfu 14.05%
# iter 1110: loss 1.3662, time 25.34ms, mfu 14.13%
# iter 1120: loss 1.3307, time 25.18ms, mfu 14.20%
# iter 1130: loss 1.3655, time 25.07ms, mfu 14.27%
# iter 1140: loss 1.3599, time 27.72ms, mfu 14.19%
# iter 1150: loss 1.3474, time 26.18ms, mfu 14.20%
# iter 1160: loss 1.3589, time 25.41ms, mfu 14.26%
# iter 1170: loss 1.3676, time 30.92ms, mfu 14.04%
# iter 1180: loss 1.3743, time 25.29ms, mfu 14.12%
# iter 1190: loss 1.3327, time 25.01ms, mfu 14.20%
# iter 1200: loss 1.3305, time 25.18ms, mfu 14.27%
# iter 1210: loss 1.3261, time 25.15ms, mfu 14.33%
# iter 1220: loss 1.3462, time 25.16ms, mfu 14.38%
# iter 1230: loss 1.3383, time 25.18ms, mfu 14.43%
# iter 1240: loss 1.3690, time 25.10ms, mfu 14.48%
# step 1250: train loss 1.2583, val loss 1.4997
# saving checkpoint to ../out/out-shakespeare-char
# iter 1250: loss 1.3255, time 6567.95ms, mfu 13.04%
# iter 1260: loss 1.3286, time 24.98ms, mfu 13.23%
# iter 1270: loss 1.3216, time 24.98ms, mfu 13.41%
# iter 1280: loss 1.2987, time 25.07ms, mfu 13.56%
# iter 1290: loss 1.3078, time 28.77ms, mfu 13.50%
# iter 1300: loss 1.3314, time 27.41ms, mfu 13.52%
# iter 1310: loss 1.3319, time 25.56ms, mfu 13.63%
# iter 1320: loss 1.3007, time 25.23ms, mfu 13.75%
# iter 1330: loss 1.3133, time 25.00ms, mfu 13.87%
# iter 1340: loss 1.3070, time 25.68ms, mfu 13.94%
# iter 1350: loss 1.3189, time 25.35ms, mfu 14.02%
# iter 1360: loss 1.3150, time 25.26ms, mfu 14.10%
# iter 1370: loss 1.3246, time 25.31ms, mfu 14.17%
# iter 1380: loss 1.3142, time 25.28ms, mfu 14.23%
# iter 1390: loss 1.2731, time 25.53ms, mfu 14.28%
# iter 1400: loss 1.2946, time 25.61ms, mfu 14.31%
# iter 1410: loss 1.2896, time 25.19ms, mfu 14.36%
# iter 1420: loss 1.2878, time 25.27ms, mfu 14.41%
# iter 1430: loss 1.2850, time 26.27ms, mfu 14.39%
# iter 1440: loss 1.3090, time 25.33ms, mfu 14.43%
# iter 1450: loss 1.2903, time 25.34ms, mfu 14.46%
# iter 1460: loss 1.2983, time 25.43ms, mfu 14.49%
# iter 1470: loss 1.2911, time 25.30ms, mfu 14.52%
# iter 1480: loss 1.2623, time 30.19ms, mfu 14.31%
# iter 1490: loss 1.2993, time 25.54ms, mfu 14.34%
# step 1500: train loss 1.2104, val loss 1.4948
# saving checkpoint to ../out/out-shakespeare-char
# iter 1500: loss 1.2521, time 6474.12ms, mfu 12.91%
# iter 1510: loss 1.2752, time 25.17ms, mfu 13.11%
# iter 1520: loss 1.2634, time 25.41ms, mfu 13.27%
# iter 1530: loss 1.2676, time 25.37ms, mfu 13.42%
# iter 1540: loss 1.2655, time 25.36ms, mfu 13.55%
# iter 1550: loss 1.2876, time 25.38ms, mfu 13.67%
# iter 1560: loss 1.2905, time 25.48ms, mfu 13.77%
# iter 1570: loss 1.2876, time 25.31ms, mfu 13.87%
# iter 1580: loss 1.2401, time 24.98ms, mfu 13.98%
# iter 1590: loss 1.2836, time 26.02ms, mfu 14.02%
# iter 1600: loss 1.2773, time 24.99ms, mfu 14.12%
# iter 1610: loss 1.2524, time 25.39ms, mfu 14.18%
# iter 1620: loss 1.2941, time 27.02ms, mfu 14.15%
# iter 1630: loss 1.2522, time 24.99ms, mfu 14.23%
# iter 1640: loss 1.2347, time 25.06ms, mfu 14.30%
# iter 1650: loss 1.2881, time 28.08ms, mfu 14.20%
# iter 1660: loss 1.2482, time 25.11ms, mfu 14.27%
# iter 1670: loss 1.2437, time 25.04ms, mfu 14.34%
# iter 1680: loss 1.2561, time 25.01ms, mfu 14.40%
# iter 1690: loss 1.2748, time 25.15ms, mfu 14.45%
# iter 1700: loss 1.2530, time 25.05ms, mfu 14.50%
# iter 1710: loss 1.2512, time 24.97ms, mfu 14.55%
# iter 1720: loss 1.2350, time 24.96ms, mfu 14.59%
# iter 1730: loss 1.2565, time 25.69ms, mfu 14.59%
# iter 1740: loss 1.2434, time 25.10ms, mfu 14.62%
# step 1750: train loss 1.1656, val loss 1.4728
# saving checkpoint to ../out/out-shakespeare-char
# iter 1750: loss 1.2328, time 6509.05ms, mfu 13.16%
# iter 1760: loss 1.2689, time 25.10ms, mfu 13.34%
# iter 1770: loss 1.2647, time 25.62ms, mfu 13.46%
# iter 1780: loss 1.2220, time 25.23ms, mfu 13.60%
# iter 1790: loss 1.2351, time 25.34ms, mfu 13.72%
# iter 1800: loss 1.2378, time 25.47ms, mfu 13.82%
# iter 1810: loss 1.2295, time 26.05ms, mfu 13.87%
# iter 1820: loss 1.2368, time 24.98ms, mfu 13.98%
# iter 1830: loss 1.2188, time 29.99ms, mfu 13.83%
# iter 1840: loss 1.2107, time 25.53ms, mfu 13.91%
# iter 1850: loss 1.1962, time 26.89ms, mfu 13.91%
# iter 1860: loss 1.2318, time 28.54ms, mfu 13.83%
# iter 1870: loss 1.2245, time 24.86ms, mfu 13.96%
# iter 1880: loss 1.2189, time 30.64ms, mfu 13.78%
# iter 1890: loss 1.2147, time 25.43ms, mfu 13.87%
# iter 1900: loss 1.2053, time 25.23ms, mfu 13.97%
# iter 1910: loss 1.2168, time 25.50ms, mfu 14.04%
# iter 1920: loss 1.2470, time 25.09ms, mfu 14.13%
# iter 1930: loss 1.1974, time 24.99ms, mfu 14.21%
# iter 1940: loss 1.2051, time 33.05ms, mfu 13.92%
# iter 1950: loss 1.2104, time 25.00ms, mfu 14.03%
# iter 1960: loss 1.2045, time 25.15ms, mfu 14.11%
# iter 1970: loss 1.1897, time 24.99ms, mfu 14.20%
# iter 1980: loss 1.2117, time 25.04ms, mfu 14.27%
# iter 1990: loss 1.1887, time 25.10ms, mfu 14.34%
# step 2000: train loss 1.1297, val loss 1.4625
# saving checkpoint to ../out/out-shakespeare-char
# iter 2000: loss 1.1914, time 6472.80ms, mfu 12.91%
# iter 2010: loss 1.2074, time 24.95ms, mfu 13.12%
# iter 2020: loss 1.1933, time 25.63ms, mfu 13.27%
# iter 2030: loss 1.1955, time 25.35ms, mfu 13.42%
# iter 2040: loss 1.1864, time 25.08ms, mfu 13.57%
# iter 2050: loss 1.1707, time 25.07ms, mfu 13.70%
# iter 2060: loss 1.1958, time 25.02ms, mfu 13.83%
# iter 2070: loss 1.1891, time 25.04ms, mfu 13.94%
# iter 2080: loss 1.2005, time 25.05ms, mfu 14.04%
# iter 2090: loss 1.2041, time 25.20ms, mfu 14.12%
# iter 2100: loss 1.1532, time 25.09ms, mfu 14.20%
# iter 2110: loss 1.1959, time 30.64ms, mfu 14.00%
# iter 2120: loss 1.1682, time 24.92ms, mfu 14.10%
# iter 2130: loss 1.1875, time 25.31ms, mfu 14.17%
# iter 2140: loss 1.1812, time 25.55ms, mfu 14.22%
# iter 2150: loss 1.1887, time 25.45ms, mfu 14.27%
# iter 2160: loss 1.1873, time 30.84ms, mfu 14.05%
# iter 2170: loss 1.2000, time 25.03ms, mfu 14.14%
# iter 2180: loss 1.1854, time 25.14ms, mfu 14.22%
# iter 2190: loss 1.1452, time 25.02ms, mfu 14.29%
# iter 2200: loss 1.1569, time 25.08ms, mfu 14.35%
# iter 2210: loss 1.1857, time 26.17ms, mfu 14.35%
# iter 2220: loss 1.1971, time 25.08ms, mfu 14.41%
# iter 2230: loss 1.1635, time 25.21ms, mfu 14.45%
# iter 2240: loss 1.1560, time 25.11ms, mfu 14.50%
# step 2250: train loss 1.0882, val loss 1.4783
# iter 2250: loss 1.1567, time 6382.19ms, mfu 13.05%
# iter 2260: loss 1.1645, time 25.22ms, mfu 13.23%
# iter 2270: loss 1.1728, time 25.28ms, mfu 13.39%
# iter 2280: loss 1.1637, time 25.33ms, mfu 13.53%
# iter 2290: loss 1.1599, time 34.32ms, mfu 13.26%
# iter 2300: loss 1.1627, time 25.35ms, mfu 13.41%
# iter 2310: loss 1.1407, time 25.29ms, mfu 13.55%
# iter 2320: loss 1.1723, time 25.40ms, mfu 13.67%
# iter 2330: loss 1.1666, time 25.60ms, mfu 13.77%
# iter 2340: loss 1.2118, time 25.14ms, mfu 13.88%
# iter 2350: loss 1.1887, time 25.16ms, mfu 13.98%
# iter 2360: loss 1.1738, time 25.25ms, mfu 14.06%
# iter 2370: loss 1.1527, time 25.21ms, mfu 14.14%
# iter 2380: loss 1.1518, time 25.98ms, mfu 14.17%
# iter 2390: loss 1.1523, time 25.39ms, mfu 14.22%
# iter 2400: loss 1.1396, time 25.42ms, mfu 14.27%
# iter 2410: loss 1.1697, time 25.88ms, mfu 14.29%
# iter 2420: loss 1.1523, time 25.31ms, mfu 14.34%
# iter 2430: loss 1.1393, time 27.34ms, mfu 14.28%
# iter 2440: loss 1.1827, time 25.25ms, mfu 14.33%
# iter 2450: loss 1.1614, time 25.39ms, mfu 14.37%
# iter 2460: loss 1.1599, time 27.47ms, mfu 14.30%
# iter 2470: loss 1.1629, time 25.51ms, mfu 14.33%
# iter 2480: loss 1.1692, time 25.25ms, mfu 14.38%
# iter 2490: loss 1.1932, time 35.03ms, mfu 14.01%
# step 2500: train loss 1.0487, val loss 1.4661
# iter 2500: loss 1.1301, time 6420.78ms, mfu 12.62%
# iter 2510: loss 1.1194, time 40.67ms, mfu 12.27%
# iter 2520: loss 1.1556, time 25.23ms, mfu 12.53%
# iter 2530: loss 1.1638, time 25.42ms, mfu 12.75%
# iter 2540: loss 1.1310, time 25.11ms, mfu 12.96%
# iter 2550: loss 1.1464, time 25.13ms, mfu 13.16%
# iter 2560: loss 1.1486, time 25.96ms, mfu 13.28%
# iter 2570: loss 1.1346, time 38.82ms, mfu 12.92%
# iter 2580: loss 1.1360, time 28.01ms, mfu 12.96%
# iter 2590: loss 1.1157, time 25.64ms, mfu 13.13%
# iter 2600: loss 1.1415, time 25.08ms, mfu 13.30%
# iter 2610: loss 1.1421, time 25.18ms, mfu 13.46%
# iter 2620: loss 1.0983, time 25.36ms, mfu 13.59%
# iter 2630: loss 1.1418, time 25.18ms, mfu 13.72%
# iter 2640: loss 1.1180, time 25.12ms, mfu 13.83%
# iter 2650: loss 1.1010, time 25.30ms, mfu 13.93%
# iter 2660: loss 1.1261, time 25.30ms, mfu 14.02%
# iter 2670: loss 1.1239, time 25.41ms, mfu 14.09%
# iter 2680: loss 1.1457, time 24.93ms, mfu 14.18%
# iter 2690: loss 1.0903, time 26.85ms, mfu 14.15%
# iter 2700: loss 1.1235, time 25.11ms, mfu 14.23%
# iter 2710: loss 1.1047, time 25.41ms, mfu 14.28%
# iter 2720: loss 1.0924, time 30.55ms, mfu 14.08%
# iter 2730: loss 1.1132, time 25.26ms, mfu 14.15%
# iter 2740: loss 1.1299, time 25.27ms, mfu 14.22%
# step 2750: train loss 1.0124, val loss 1.4671
# iter 2750: loss 1.1308, time 6228.18ms, mfu 12.80%
# iter 2760: loss 1.1221, time 25.16ms, mfu 13.01%
# iter 2770: loss 1.1255, time 25.33ms, mfu 13.18%
# iter 2780: loss 1.1231, time 25.29ms, mfu 13.35%
# iter 2790: loss 1.0860, time 25.21ms, mfu 13.49%
# iter 2800: loss 1.0801, time 25.20ms, mfu 13.63%
# iter 2810: loss 1.1013, time 25.30ms, mfu 13.75%
# iter 2820: loss 1.1058, time 25.62ms, mfu 13.83%
# iter 2830: loss 1.1226, time 25.27ms, mfu 13.93%
# iter 2840: loss 1.0762, time 25.21ms, mfu 14.02%
# iter 2850: loss 1.0998, time 25.29ms, mfu 14.10%
# iter 2860: loss 1.1051, time 25.29ms, mfu 14.17%
# iter 2870: loss 1.1184, time 25.39ms, mfu 14.23%
# iter 2880: loss 1.1236, time 25.37ms, mfu 14.28%
# iter 2890: loss 1.0995, time 25.44ms, mfu 14.32%
# iter 2900: loss 1.0759, time 25.59ms, mfu 14.35%
# iter 2910: loss 1.0959, time 25.38ms, mfu 14.39%
# iter 2920: loss 1.0986, time 25.48ms, mfu 14.42%
# iter 2930: loss 1.0668, time 25.43ms, mfu 14.45%
# iter 2940: loss 1.1157, time 27.65ms, mfu 14.36%
# iter 2950: loss 1.1070, time 25.48ms, mfu 14.39%
# iter 2960: loss 1.0857, time 25.31ms, mfu 14.43%
# iter 2970: loss 1.0742, time 25.31ms, mfu 14.47%
# iter 2980: loss 1.0902, time 25.24ms, mfu 14.50%
# iter 2990: loss 1.0846, time 25.32ms, mfu 14.53%
# step 3000: train loss 0.9792, val loss 1.4763
# iter 3000: loss 1.0667, time 6211.30ms, mfu 13.08%
# iter 3010: loss 1.1052, time 25.17ms, mfu 13.26%
# iter 3020: loss 1.1003, time 25.34ms, mfu 13.41%
# iter 3030: loss 1.0708, time 25.49ms, mfu 13.54%
# iter 3040: loss 1.0881, time 25.19ms, mfu 13.67%
# iter 3050: loss 1.0541, time 25.32ms, mfu 13.78%
# iter 3060: loss 1.0873, time 25.36ms, mfu 13.88%
# iter 3070: loss 1.0683, time 25.29ms, mfu 13.97%
# iter 3080: loss 1.0844, time 25.30ms, mfu 14.05%
# iter 3090: loss 1.1003, time 25.36ms, mfu 14.12%
# iter 3100: loss 1.0758, time 26.04ms, mfu 14.15%
# iter 3110: loss 1.0813, time 25.48ms, mfu 14.20%
# iter 3120: loss 1.0542, time 25.61ms, mfu 14.24%
# iter 3130: loss 1.0790, time 25.34ms, mfu 14.30%
# iter 3140: loss 1.0633, time 25.59ms, mfu 14.33%
# iter 3150: loss 1.0495, time 25.38ms, mfu 14.37%
# iter 3160: loss 1.0698, time 25.68ms, mfu 14.39%
# iter 3170: loss 1.0595, time 25.40ms, mfu 14.42%
# iter 3180: loss 1.0604, time 27.95ms, mfu 14.32%
# iter 3190: loss 1.0579, time 25.47ms, mfu 14.36%
# iter 3200: loss 1.0842, time 25.20ms, mfu 14.41%
# iter 3210: loss 1.0539, time 25.41ms, mfu 14.44%
# iter 3220: loss 1.0469, time 36.72ms, mfu 14.01%
# iter 3230: loss 1.0616, time 25.22ms, mfu 14.10%
# iter 3240: loss 1.0844, time 25.24ms, mfu 14.17%
# step 3250: train loss 0.9426, val loss 1.4909
# iter 3250: loss 1.0533, time 6206.44ms, mfu 12.76%
# iter 3260: loss 1.0333, time 25.08ms, mfu 12.97%
# iter 3270: loss 1.0354, time 25.14ms, mfu 13.17%
# iter 3280: loss 1.0279, time 25.12ms, mfu 13.34%
# iter 3290: loss 1.0516, time 25.62ms, mfu 13.47%
# iter 3300: loss 1.0440, time 25.55ms, mfu 13.58%
# iter 3310: loss 1.0527, time 25.50ms, mfu 13.69%
# iter 3320: loss 1.0716, time 25.22ms, mfu 13.81%
# iter 3330: loss 1.0096, time 24.92ms, mfu 13.93%
# iter 3340: loss 1.0547, time 29.26ms, mfu 13.81%
# iter 3350: loss 1.0641, time 25.14ms, mfu 13.92%
# iter 3360: loss 1.0252, time 27.13ms, mfu 13.91%
# iter 3370: loss 1.0427, time 26.14ms, mfu 13.95%
# iter 3380: loss 1.0566, time 25.43ms, mfu 14.03%
# iter 3390: loss 1.0414, time 25.60ms, mfu 14.08%
# iter 3400: loss 1.0467, time 31.01ms, mfu 13.88%
# iter 3410: loss 1.0050, time 25.05ms, mfu 13.99%
# iter 3420: loss 1.0471, time 25.39ms, mfu 14.06%
# iter 3430: loss 1.0299, time 27.24ms, mfu 14.03%
# iter 3440: loss 1.0232, time 25.30ms, mfu 14.11%
# iter 3450: loss 1.0446, time 25.46ms, mfu 14.17%
# iter 3460: loss 1.0364, time 27.42ms, mfu 14.11%
# iter 3470: loss 1.0146, time 25.10ms, mfu 14.19%
# iter 3480: loss 1.0054, time 27.00ms, mfu 14.16%
# iter 3490: loss 1.0245, time 25.26ms, mfu 14.22%
# step 3500: train loss 0.9144, val loss 1.4913
# iter 3500: loss 1.0326, time 6293.03ms, mfu 12.81%
# iter 3510: loss 1.0411, time 25.31ms, mfu 13.01%
# iter 3520: loss 1.0167, time 25.37ms, mfu 13.18%
# iter 3530: loss 1.0583, time 25.51ms, mfu 13.33%
# iter 3540: loss 1.0185, time 25.64ms, mfu 13.46%
# iter 3550: loss 1.0492, time 25.48ms, mfu 13.58%
# iter 3560: loss 1.0170, time 28.92ms, mfu 13.51%
# iter 3570: loss 1.0182, time 26.48ms, mfu 13.58%
# iter 3580: loss 1.0257, time 25.64ms, mfu 13.68%
# iter 3590: loss 1.0200, time 40.50ms, mfu 13.23%
# iter 3600: loss 1.0135, time 25.04ms, mfu 13.41%
# iter 3610: loss 1.0468, time 30.80ms, mfu 13.28%
# iter 3620: loss 1.0261, time 25.16ms, mfu 13.44%
# iter 3630: loss 1.0280, time 118.79ms, mfu 12.41%
# iter 3640: loss 1.0323, time 25.57ms, mfu 12.63%
# iter 3650: loss 1.0100, time 25.37ms, mfu 12.84%
# iter 3660: loss 1.0206, time 25.56ms, mfu 13.02%
# iter 3670: loss 1.0105, time 33.05ms, mfu 12.85%
# iter 3680: loss 1.0116, time 25.37ms, mfu 13.04%
# iter 3690: loss 1.0062, time 25.44ms, mfu 13.21%
# iter 3700: loss 1.0039, time 42.47ms, mfu 12.77%
# iter 3710: loss 1.0228, time 25.02ms, mfu 12.99%
# iter 3720: loss 1.0222, time 25.35ms, mfu 13.17%
# iter 3730: loss 1.0339, time 25.04ms, mfu 13.34%
# iter 3740: loss 1.0167, time 25.27ms, mfu 13.49%
# step 3750: train loss 0.8820, val loss 1.5019
# iter 3750: loss 1.0059, time 6205.26ms, mfu 12.15%
# iter 3760: loss 1.0152, time 25.03ms, mfu 12.43%
# iter 3770: loss 1.0021, time 25.16ms, mfu 12.67%
# iter 3780: loss 1.0065, time 25.13ms, mfu 12.89%
# iter 3790: loss 1.0334, time 25.13ms, mfu 13.09%
# iter 3800: loss 0.9887, time 28.19ms, mfu 13.11%
# iter 3810: loss 1.0195, time 27.62ms, mfu 13.15%
# iter 3820: loss 1.0111, time 30.74ms, mfu 13.06%
# iter 3830: loss 1.0142, time 24.96ms, mfu 13.25%
# iter 3840: loss 1.0104, time 25.35ms, mfu 13.40%
# iter 3850: loss 1.0257, time 25.35ms, mfu 13.54%
# iter 3860: loss 1.0155, time 28.87ms, mfu 13.48%
# iter 3870: loss 1.0321, time 25.07ms, mfu 13.62%
# iter 3880: loss 0.9952, time 25.03ms, mfu 13.76%
# iter 3890: loss 1.0214, time 28.97ms, mfu 13.67%
# iter 3900: loss 0.9863, time 25.09ms, mfu 13.80%
# iter 3910: loss 1.0131, time 25.00ms, mfu 13.91%
# iter 3920: loss 1.0052, time 25.18ms, mfu 14.01%
# iter 3930: loss 1.0025, time 33.43ms, mfu 13.73%
# iter 3940: loss 1.0228, time 25.23ms, mfu 13.84%
# iter 3950: loss 1.0077, time 26.38ms, mfu 13.87%
# iter 3960: loss 1.0076, time 26.81ms, mfu 13.88%
# iter 3970: loss 1.0047, time 26.78ms, mfu 13.89%
# iter 3980: loss 1.0195, time 25.36ms, mfu 13.98%
# iter 3990: loss 1.0080, time 25.22ms, mfu 14.06%
# step 4000: train loss 0.8579, val loss 1.5177
# iter 4000: loss 1.0092, time 6327.45ms, mfu 12.66%
# iter 4010: loss 0.9805, time 25.14ms, mfu 12.88%
# iter 4020: loss 0.9727, time 25.15ms, mfu 13.08%
# iter 4030: loss 0.9575, time 26.80ms, mfu 13.17%
# iter 4040: loss 0.9990, time 24.98ms, mfu 13.35%
# iter 4050: loss 0.9605, time 27.19ms, mfu 13.39%
# iter 4060: loss 0.9807, time 25.16ms, mfu 13.54%
# iter 4070: loss 0.9836, time 25.11ms, mfu 13.68%
# iter 4080: loss 1.0125, time 25.30ms, mfu 13.79%
# iter 4090: loss 0.9741, time 25.16ms, mfu 13.90%
# iter 4100: loss 0.9993, time 25.42ms, mfu 13.98%
# iter 4110: loss 0.9744, time 26.09ms, mfu 14.02%
# iter 4120: loss 1.0110, time 25.34ms, mfu 14.09%
# iter 4130: loss 0.9667, time 29.65ms, mfu 13.94%
# iter 4140: loss 0.9961, time 25.20ms, mfu 14.03%
# iter 4150: loss 0.9934, time 28.20ms, mfu 13.96%
# iter 4160: loss 0.9924, time 26.92ms, mfu 13.95%
# iter 4170: loss 0.9840, time 26.06ms, mfu 13.99%
# iter 4180: loss 0.9614, time 95.29ms, mfu 12.99%
# iter 4190: loss 0.9980, time 24.90ms, mfu 13.19%
# iter 4200: loss 1.0109, time 25.25ms, mfu 13.35%
# iter 4210: loss 0.9788, time 26.43ms, mfu 13.43%
# iter 4220: loss 0.9719, time 25.54ms, mfu 13.56%
# iter 4230: loss 0.9592, time 25.39ms, mfu 13.67%
# iter 4240: loss 0.9909, time 26.25ms, mfu 13.73%
# step 4250: train loss 0.8369, val loss 1.5207
# iter 4250: loss 0.9793, time 6197.28ms, mfu 12.37%
# iter 4260: loss 0.9788, time 40.86ms, mfu 12.04%
# iter 4270: loss 0.9638, time 25.42ms, mfu 12.31%
# iter 4280: loss 0.9656, time 24.96ms, mfu 12.58%
# iter 4290: loss 0.9843, time 25.05ms, mfu 12.82%
# iter 4300: loss 0.9867, time 98.93ms, mfu 11.91%
# iter 4310: loss 0.9622, time 27.53ms, mfu 12.08%
# iter 4320: loss 0.9583, time 25.47ms, mfu 12.34%
# iter 4330: loss 0.9645, time 25.60ms, mfu 12.57%
# iter 4340: loss 0.9621, time 25.49ms, mfu 12.78%
# iter 4350: loss 0.9957, time 28.23ms, mfu 12.83%
# iter 4360: loss 0.9729, time 25.37ms, mfu 13.02%
# iter 4370: loss 0.9627, time 25.52ms, mfu 13.18%
# iter 4380: loss 0.9699, time 25.21ms, mfu 13.35%
# iter 4390: loss 0.9745, time 35.07ms, mfu 13.08%
# iter 4400: loss 0.9444, time 25.47ms, mfu 13.24%
# iter 4410: loss 0.9771, time 25.28ms, mfu 13.40%
# iter 4420: loss 0.9898, time 35.10ms, mfu 13.13%
# iter 4430: loss 0.9642, time 25.25ms, mfu 13.29%
# iter 4440: loss 0.9610, time 28.08ms, mfu 13.30%
# iter 4450: loss 0.9644, time 25.40ms, mfu 13.44%
# iter 4460: loss 0.9482, time 25.43ms, mfu 13.57%
# iter 4470: loss 0.9647, time 25.58ms, mfu 13.67%
# iter 4480: loss 0.9650, time 25.24ms, mfu 13.79%
# iter 4490: loss 0.9517, time 25.29ms, mfu 13.89%
# step 4500: train loss 0.8191, val loss 1.5327
# iter 4500: loss 0.9723, time 6222.71ms, mfu 12.51%
# iter 4510: loss 0.9615, time 25.21ms, mfu 12.74%
# iter 4520: loss 0.9673, time 25.30ms, mfu 12.95%
# iter 4530: loss 0.9814, time 25.08ms, mfu 13.14%
# iter 4540: loss 0.9796, time 25.07ms, mfu 13.32%
# iter 4550: loss 0.9493, time 25.16ms, mfu 13.48%
# iter 4560: loss 0.9605, time 26.28ms, mfu 13.55%
# iter 4570: loss 0.9802, time 25.22ms, mfu 13.68%
# iter 4580: loss 0.9540, time 26.91ms, mfu 13.70%
# iter 4590: loss 0.9605, time 25.42ms, mfu 13.81%
# iter 4600: loss 0.9598, time 25.33ms, mfu 13.90%
# iter 4610: loss 0.9690, time 31.68ms, mfu 13.69%
# iter 4620: loss 0.9672, time 25.45ms, mfu 13.79%
# iter 4630: loss 0.9375, time 25.48ms, mfu 13.88%
# iter 4640: loss 0.9393, time 25.39ms, mfu 13.97%
# iter 4650: loss 0.9476, time 25.18ms, mfu 14.06%
# iter 4660: loss 0.9480, time 25.89ms, mfu 14.10%
# iter 4670: loss 0.9681, time 95.92ms, mfu 13.08%
# iter 4680: loss 0.9492, time 25.03ms, mfu 13.26%
# iter 4690: loss 0.9468, time 27.45ms, mfu 13.30%
# iter 4700: loss 0.9658, time 77.82ms, mfu 12.45%
# iter 4710: loss 0.9720, time 25.48ms, mfu 12.68%
# iter 4720: loss 0.9682, time 25.50ms, mfu 12.88%
# iter 4730: loss 0.9704, time 25.26ms, mfu 13.07%
# iter 4740: loss 0.9692, time 27.93ms, mfu 13.10%
# step 4750: train loss 0.8022, val loss 1.5435
# iter 4750: loss 0.9576, time 6224.60ms, mfu 11.80%
# iter 4760: loss 0.9347, time 25.37ms, mfu 12.09%
# iter 4770: loss 0.9354, time 27.07ms, mfu 12.27%
# iter 4780: loss 0.9575, time 25.58ms, mfu 12.50%
# iter 4790: loss 0.9417, time 29.01ms, mfu 12.54%
# iter 4800: loss 0.9505, time 25.30ms, mfu 12.77%
# iter 4810: loss 0.9528, time 31.06ms, mfu 12.70%
# iter 4820: loss 0.9248, time 25.91ms, mfu 12.87%
# iter 4830: loss 0.9312, time 25.97ms, mfu 13.02%
# iter 4840: loss 0.9674, time 25.60ms, mfu 13.18%
# iter 4850: loss 0.9550, time 30.87ms, mfu 13.08%
# iter 4860: loss 0.9524, time 25.58ms, mfu 13.23%
# iter 4870: loss 0.9388, time 25.05ms, mfu 13.40%
# iter 4880: loss 0.9495, time 28.27ms, mfu 13.39%
# iter 4890: loss 0.9276, time 24.99ms, mfu 13.54%
# iter 4900: loss 0.9352, time 25.18ms, mfu 13.68%
# iter 4910: loss 0.9681, time 37.45ms, mfu 13.31%
# iter 4920: loss 0.9631, time 25.47ms, mfu 13.45%
# iter 4930: loss 0.9414, time 25.64ms, mfu 13.56%
# iter 4940: loss 0.9598, time 25.27ms, mfu 13.69%
# iter 4950: loss 0.9830, time 27.62ms, mfu 13.67%
# iter 4960: loss 0.9778, time 25.53ms, mfu 13.77%
# iter 4970: loss 0.9549, time 25.52ms, mfu 13.86%
# iter 4980: loss 0.9358, time 25.33ms, mfu 13.95%
# iter 4990: loss 0.9494, time 25.35ms, mfu 14.03%
# step 5000: train loss 0.7915, val loss 1.5488
# iter 5000: loss 0.9408, time 6242.38ms, mfu 12.63%
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# VBox(children=(Label(value='0.092 MB of 0.092 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iter</td><td>▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>lr</td><td>▁████▇▇▆▆▅▅▄▄▃▃▃▂▂▂▂▂</td></tr><tr><td>mfu</td><td>▁████████████████████</td></tr><tr><td>test/loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>█▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iter</td><td>5000</td></tr><tr><td>lr</td><td>0.0001</td></tr><tr><td>mfu</td><td>14.03135</td></tr><tr><td>test/loss</td><td>1.63572</td></tr><tr><td>train/loss</td><td>0.79149</td></tr><tr><td>val/loss</td><td>1.54881</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">TransformerLM</strong> at: <a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/yb0577xz' target="_blank">https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/yb0577xz</a><br/>Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20240118_180608-yb0577xz/logs</code>
# DONE.

# %%
prompt = 'Romeo'

char_to_idx = meta_data['stoi']
idx_to_char = meta_data['itos']
prompt_idx = torch.from_numpy(np.array([char_to_idx[c] for c in prompt])).unsqueeze(0).to('cuda')
sample_gen = model.generate(prompt_idx, max_new_tokens=1000, temperature=1.0, top_k=None)[0]
sample_gen = ''.join([idx_to_char[idx] for idx in np.array(sample_gen.cpu())])
print(sample_gen)
# Out:
# Romeo, O, that seest us to arms else,
# The mansforest men and duch mourners challough the wreck,
# When when you excuses my datheress put from Time.
#
# GLOUCESTER:
# This should change with some cause won, making lies,
# Because that I can all know
# The mutiny of the wonderings of itself;
# It will let me all plength from the norance,
# For blessing thy fury is charged with no seed.
#
# HENRY BOLINGBROKE:
# By him what enter'd shall in fail or breath?
# O, would answer York's land is stended from;
# And thus to struck away the sacrificed!
# But nothing gods stand up his that circum,
# Dakest up denial and barbarred that I may,
# God to fight it, and he will applied.
#
# hurt competitch:
# Bring it not, mamorrow, as well,
# This trudge would unpeople them in the straw;
# For 'tis too view too might for they:
# Ah, brother blood in war in the seat.
# Saddle hold, thou look'st entering fires,
# me a bad, as I live, I do not not deceased
# In mine issue of kindred's loss; who, is Norfolk,
# The king colder Hastings, his son: the nobles use
# H

# %% [markdown]
# ## Abstract Transformer Model (Positional Symbols)

# %%
model_args = dict(
    vocab_size=vocab_size, d_model=384, n_layers=6, n_heads_enc=4, n_heads_abs=2, dff=None,
    symbol_retrieval='positional_symbols', symbol_retrieval_kwargs=dict(symbol_dim=384, max_symbols=block_size), # FIXME make names consistent: d_model, model_dim
    dropout_rate=0.2, activation='relu', norm_first=True, max_block_size=256, bias=True)
model = abstracttransformer_lm = AbstractTransformerLM(**model_args).to(device)

# %%
torchinfo.summary(model, input_data=torch.randint(0, 10, size=(1,256)), device='cuda')
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# AbstractTransformerLM                                   [1, 1, 65]                --
# ├─ModuleDict: 1-1                                       --                        --
# │    └─Embedding: 2-1                                   [1, 256, 384]             24,960
# │    └─Embedding: 2-2                                   [256, 384]                98,304
# │    └─ModuleList: 2-3                                  --                        --
# │    │    └─AbstractEncoderBlock: 3-1                   [1, 256, 384]             2,316,288
# │    │    └─AbstractEncoderBlock: 3-14                  --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-3                   --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-4                   [1, 256, 384]             2,316,288
# │    │    └─AbstractEncoderBlock: 3-14                  --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-6                   --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-7                   [1, 256, 384]             2,316,288
# │    │    └─AbstractEncoderBlock: 3-14                  --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-9                   --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-10                  [1, 256, 384]             2,316,288
# │    │    └─AbstractEncoderBlock: 3-14                  --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-12                  --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-13                  [1, 256, 384]             2,316,288
# │    │    └─AbstractEncoderBlock: 3-14                  --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-15                  --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-16                  [1, 256, 384]             2,316,288
# │    └─Linear: 2-4                                      [1, 1, 65]                25,025
# =========================================================================================================
# Total params: 25,230,401
# Trainable params: 25,230,401
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 183.31
# =========================================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 39.32
# Params size (MB): 29.38
# Estimated Total Size (MB): 68.71
# =========================================================================================================

# %%
# torchinfo overcounts # of params... something to do with symbolic attention shared across layers
# this is the correct number (similar to TransformerLM)

num_params = model.get_num_params() #sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'# of params {num_params:,}')
# Out:
# # of params 13,456,193

# %%
# TODO: can we implement in a way that torchinfo can understand? i.e., without "recursive" and overcounting

# %% [markdown]
# ### Training

# %%
# grad scaler
scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16'))
# optimizer
optimizer = configure_optimizers(model, weight_decay, learning_rate, (beta1, beta2), device_type=device)
# Out:
# num decayed parameter tensors: 40, with 13,517,568 parameters
# num non-decayed parameter tensors: 61, with 36,929 parameters
# using fused AdamW: True

# %%
def get_lr(it):
    # 1) linear warmup for warmup_iters steps
    if it < warmup_iters:
        return learning_rate * it / warmup_iters
    # 2) if it > lr_decay_iters, return min learning rate
    if it > lr_decay_iters:
        return min_lr
    # 3) in between, use cosine decay down to min learning rate
    decay_ratio = (it - warmup_iters) / (lr_decay_iters - warmup_iters)
    assert 0 <= decay_ratio <= 1
    coeff = 0.5 * (1.0 + math.cos(math.pi * decay_ratio)) # coeff ranges 0..1
    return min_lr + coeff * (learning_rate - min_lr)

# %%
@torch.no_grad()
def eval_model(model, ctx=None):

    ctx = nullcontext() if ctx is None else ctx
    out = {}
    model.eval()
    for split in ['train', 'val', 'test']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            with ctx:
                logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[f'{split}/loss'] = losses.mean()
    model.train()
    return out

# %%
train_kwargs = dict(
    model=model, get_batch=get_batch, batch_size=batch_size, max_iters=max_iters,
    optimizer=optimizer, scaler=scaler, get_lr=get_lr, eval_model=eval_model,
    compile=True, grad_clip=0, gradient_accumulation_steps=gradient_accumulation_steps,
    eval_main_metric='val/loss', eval_interval=eval_interval, always_save_checkpoint=always_save_checkpoint, out_dir=out_dir,
    log_interval=10, wandb_log=True, wandb_init_kwargs=dict(project=wandb_project, name='AbstractTransformerLM (Positional Symbols)'), 
    ckpt_dict=dict(model_args=model_args), track_mfu=True,
    master_process=True, ddp=False, device_type='cuda')

# %%
train_model(**train_kwargs)
# Out:
# Tracking run with wandb version 0.16.2
# Run data is saved locally in <code>/gpfs/gibbs/project/lafferty/ma2393/abstract_transformer/experiments/wandb/run-20240118_190436-1rqt61ns</code>
# Syncing run <strong><a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/1rqt61ns' target="_blank">AbstractTransformerLM (Positional Symbols</a></strong> to <a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char' target="_blank">https://wandb.ai/awni00/abstract_transformer--shakespeare_char</a>
#  View run at <a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/1rqt61ns' target="_blank">https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/1rqt61ns</a>
# compiling model... done compiling.
# starting training loop...
# step 0: train loss 4.5987, val loss 4.5918
# iter 0: loss 4.6089, time 30581.86ms, mfu -100.00%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 10: loss 3.4847, time 43.66ms, mfu 10.99%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 20: loss 3.0159, time 40.67ms, mfu 11.07%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 30: loss 2.8049, time 40.55ms, mfu 11.15%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 40: loss 2.6825, time 40.60ms, mfu 11.21%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 50: loss 2.5872, time 41.11ms, mfu 11.26%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 60: loss 2.5604, time 40.51ms, mfu 11.32%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 70: loss 2.5231, time 40.43ms, mfu 11.37%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 80: loss 2.5323, time 40.45ms, mfu 11.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 90: loss 2.5095, time 40.44ms, mfu 11.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 100: loss 2.5402, time 40.62ms, mfu 11.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 110: loss 2.4693, time 42.09ms, mfu 11.49%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 120: loss 2.4594, time 41.06ms, mfu 11.51%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 130: loss 2.4524, time 40.40ms, mfu 11.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 140: loss 2.4272, time 40.88ms, mfu 11.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 150: loss 2.3933, time 40.49ms, mfu 11.59%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 160: loss 2.3680, time 40.50ms, mfu 11.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 170: loss 2.2771, time 40.44ms, mfu 11.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 180: loss 2.2219, time 40.53ms, mfu 11.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 190: loss 2.1845, time 40.48ms, mfu 11.68%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 200: loss 2.1080, time 40.52ms, mfu 11.70%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 210: loss 2.0910, time 40.40ms, mfu 11.71%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 220: loss 2.0755, time 40.43ms, mfu 11.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 230: loss 2.0020, time 40.63ms, mfu 11.74%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 240: loss 1.9814, time 42.01ms, mfu 11.70%
# step 250: train loss 1.8889, val loss 1.9810
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 250: loss 1.9655, time 8982.20ms, mfu 10.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 260: loss 1.9005, time 40.88ms, mfu 10.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 270: loss 1.9013, time 41.91ms, mfu 10.74%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 280: loss 1.8877, time 40.61ms, mfu 10.85%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 290: loss 1.8554, time 40.44ms, mfu 10.95%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 300: loss 1.8641, time 40.59ms, mfu 11.03%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 310: loss 1.8386, time 40.39ms, mfu 11.12%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 320: loss 1.7876, time 40.48ms, mfu 11.19%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 330: loss 1.7963, time 40.40ms, mfu 11.26%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 340: loss 1.7237, time 40.46ms, mfu 11.32%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 350: loss 1.7310, time 40.52ms, mfu 11.37%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 360: loss 1.7630, time 40.48ms, mfu 11.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 370: loss 1.7187, time 40.59ms, mfu 11.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 380: loss 1.7274, time 40.48ms, mfu 11.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 390: loss 1.6952, time 40.80ms, mfu 11.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 400: loss 1.6839, time 40.49ms, mfu 11.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 410: loss 1.6904, time 40.52ms, mfu 11.59%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 420: loss 1.6588, time 40.41ms, mfu 11.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 430: loss 1.6659, time 40.44ms, mfu 11.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 440: loss 1.6571, time 40.44ms, mfu 11.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 450: loss 1.6345, time 41.01ms, mfu 11.67%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 460: loss 1.6126, time 41.86ms, mfu 11.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 470: loss 1.6405, time 40.67ms, mfu 11.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 480: loss 1.6347, time 40.73ms, mfu 11.67%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 490: loss 1.6224, time 40.76ms, mfu 11.68%
# step 500: train loss 1.5332, val loss 1.7085
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 500: loss 1.5855, time 8975.19ms, mfu 10.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 510: loss 1.6159, time 40.75ms, mfu 10.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 520: loss 1.6350, time 40.66ms, mfu 10.76%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 530: loss 1.5604, time 41.32ms, mfu 10.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 540: loss 1.5883, time 40.72ms, mfu 10.94%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 550: loss 1.5790, time 40.78ms, mfu 11.02%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 560: loss 1.5503, time 40.71ms, mfu 11.10%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 570: loss 1.5630, time 40.66ms, mfu 11.17%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 580: loss 1.5673, time 40.97ms, mfu 11.22%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 590: loss 1.5822, time 40.72ms, mfu 11.28%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 600: loss 1.5492, time 41.21ms, mfu 11.31%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 610: loss 1.5448, time 40.69ms, mfu 11.36%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 620: loss 1.5310, time 40.75ms, mfu 11.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 630: loss 1.5328, time 40.84ms, mfu 11.44%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 640: loss 1.5012, time 40.68ms, mfu 11.47%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 650: loss 1.5392, time 40.95ms, mfu 11.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 660: loss 1.5223, time 40.75ms, mfu 11.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 670: loss 1.4958, time 40.73ms, mfu 11.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 680: loss 1.4813, time 40.79ms, mfu 11.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 690: loss 1.5009, time 41.06ms, mfu 11.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 700: loss 1.4868, time 40.65ms, mfu 11.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 710: loss 1.4656, time 41.09ms, mfu 11.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 720: loss 1.4509, time 40.70ms, mfu 11.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 730: loss 1.4455, time 40.92ms, mfu 11.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 740: loss 1.4800, time 40.62ms, mfu 11.66%
# step 750: train loss 1.3960, val loss 1.5913
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 750: loss 1.4393, time 8971.08ms, mfu 10.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 760: loss 1.4501, time 40.78ms, mfu 10.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 770: loss 1.4735, time 40.43ms, mfu 10.75%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 780: loss 1.4881, time 40.37ms, mfu 10.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 790: loss 1.4407, time 41.04ms, mfu 10.94%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 800: loss 1.4817, time 40.76ms, mfu 11.03%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 810: loss 1.4342, time 41.07ms, mfu 11.09%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 820: loss 1.4734, time 40.66ms, mfu 11.16%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 830: loss 1.4281, time 40.99ms, mfu 11.22%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 840: loss 1.4367, time 40.47ms, mfu 11.28%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 850: loss 1.4583, time 40.34ms, mfu 11.34%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 860: loss 1.4253, time 40.27ms, mfu 11.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 870: loss 1.4249, time 40.44ms, mfu 11.44%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 880: loss 1.4286, time 40.29ms, mfu 11.49%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 890: loss 1.4296, time 40.26ms, mfu 11.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 900: loss 1.4238, time 40.51ms, mfu 11.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 910: loss 1.3790, time 40.39ms, mfu 11.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 920: loss 1.4216, time 40.92ms, mfu 11.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 930: loss 1.4135, time 40.63ms, mfu 11.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 940: loss 1.4228, time 40.76ms, mfu 11.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 950: loss 1.4276, time 40.27ms, mfu 11.67%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 960: loss 1.3741, time 40.27ms, mfu 11.69%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 970: loss 1.3523, time 40.59ms, mfu 11.71%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 980: loss 1.3837, time 40.22ms, mfu 11.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 990: loss 1.4281, time 40.59ms, mfu 11.74%
# step 1000: train loss 1.3207, val loss 1.5330
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1000: loss 1.3991, time 8918.36ms, mfu 10.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1010: loss 1.3759, time 40.45ms, mfu 10.70%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1020: loss 1.4132, time 40.40ms, mfu 10.82%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1030: loss 1.3760, time 40.34ms, mfu 10.92%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1040: loss 1.3800, time 41.09ms, mfu 11.00%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1050: loss 1.4111, time 40.58ms, mfu 11.08%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1060: loss 1.3727, time 40.60ms, mfu 11.15%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1070: loss 1.3719, time 40.48ms, mfu 11.22%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1080: loss 1.3653, time 40.67ms, mfu 11.28%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1090: loss 1.3433, time 40.71ms, mfu 11.33%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1100: loss 1.3004, time 41.09ms, mfu 11.37%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1110: loss 1.3560, time 40.44ms, mfu 11.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1120: loss 1.3510, time 40.51ms, mfu 11.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1130: loss 1.3457, time 40.49ms, mfu 11.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1140: loss 1.3544, time 40.35ms, mfu 11.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1150: loss 1.3234, time 40.98ms, mfu 11.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1160: loss 1.3320, time 40.45ms, mfu 11.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1170: loss 1.3224, time 40.80ms, mfu 11.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1180: loss 1.3522, time 40.86ms, mfu 11.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1190: loss 1.3507, time 40.73ms, mfu 11.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1200: loss 1.3512, time 40.65ms, mfu 11.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1210: loss 1.3624, time 40.78ms, mfu 11.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1220: loss 1.3097, time 40.77ms, mfu 11.67%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1230: loss 1.3396, time 40.80ms, mfu 11.68%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1240: loss 1.3331, time 40.78ms, mfu 11.69%
# step 1250: train loss 1.2650, val loss 1.4941
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1250: loss 1.3128, time 8982.43ms, mfu 10.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1260: loss 1.3535, time 40.66ms, mfu 10.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1270: loss 1.3237, time 40.85ms, mfu 10.76%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1280: loss 1.3140, time 40.71ms, mfu 10.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1290: loss 1.3058, time 40.71ms, mfu 10.96%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1300: loss 1.3156, time 40.72ms, mfu 11.04%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1310: loss 1.3140, time 40.65ms, mfu 11.11%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1320: loss 1.2841, time 40.75ms, mfu 11.18%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1330: loss 1.3164, time 40.61ms, mfu 11.24%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1340: loss 1.3009, time 41.16ms, mfu 11.28%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1350: loss 1.2993, time 40.75ms, mfu 11.33%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1360: loss 1.3245, time 41.00ms, mfu 11.37%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1370: loss 1.3064, time 40.74ms, mfu 11.41%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1380: loss 1.3162, time 40.79ms, mfu 11.45%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1390: loss 1.2945, time 40.68ms, mfu 11.48%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1400: loss 1.3150, time 40.69ms, mfu 11.51%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1410: loss 1.2837, time 40.72ms, mfu 11.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1420: loss 1.3193, time 40.50ms, mfu 11.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1430: loss 1.2895, time 40.90ms, mfu 11.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1440: loss 1.2925, time 40.57ms, mfu 11.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1450: loss 1.2939, time 41.01ms, mfu 11.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1460: loss 1.3007, time 40.66ms, mfu 11.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1470: loss 1.2738, time 40.80ms, mfu 11.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1480: loss 1.3318, time 40.51ms, mfu 11.67%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1490: loss 1.2711, time 40.58ms, mfu 11.68%
# step 1500: train loss 1.2212, val loss 1.4899
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1500: loss 1.3138, time 8983.69ms, mfu 10.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1510: loss 1.2980, time 41.15ms, mfu 10.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1520: loss 1.2765, time 40.77ms, mfu 10.75%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1530: loss 1.2605, time 40.94ms, mfu 10.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1540: loss 1.2907, time 40.83ms, mfu 10.93%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1550: loss 1.2762, time 40.54ms, mfu 11.02%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1560: loss 1.2917, time 40.42ms, mfu 11.11%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1570: loss 1.2808, time 40.99ms, mfu 11.17%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1580: loss 1.2949, time 40.64ms, mfu 11.23%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1590: loss 1.2685, time 40.51ms, mfu 11.29%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1600: loss 1.2628, time 40.44ms, mfu 11.35%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1610: loss 1.2652, time 40.48ms, mfu 11.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1620: loss 1.2930, time 41.02ms, mfu 11.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1630: loss 1.2383, time 40.68ms, mfu 11.47%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1640: loss 1.2958, time 40.73ms, mfu 11.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1650: loss 1.2716, time 40.48ms, mfu 11.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1660: loss 1.2526, time 40.53ms, mfu 11.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1670: loss 1.2691, time 40.39ms, mfu 11.59%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1680: loss 1.2837, time 40.41ms, mfu 11.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1690: loss 1.2791, time 40.63ms, mfu 11.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1700: loss 1.2613, time 40.58ms, mfu 11.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1710: loss 1.2491, time 40.84ms, mfu 11.67%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1720: loss 1.2704, time 40.71ms, mfu 11.68%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1730: loss 1.2433, time 41.11ms, mfu 11.68%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1740: loss 1.2617, time 40.64ms, mfu 11.69%
# step 1750: train loss 1.1809, val loss 1.4601
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1750: loss 1.2528, time 8991.22ms, mfu 10.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1760: loss 1.2861, time 40.74ms, mfu 10.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1770: loss 1.2499, time 40.60ms, mfu 10.77%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1780: loss 1.2642, time 40.65ms, mfu 10.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1790: loss 1.2764, time 41.07ms, mfu 10.95%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1800: loss 1.2417, time 40.59ms, mfu 11.04%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1810: loss 1.2348, time 41.05ms, mfu 11.10%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1820: loss 1.2164, time 40.78ms, mfu 11.17%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1830: loss 1.2432, time 42.23ms, mfu 11.19%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1840: loss 1.2560, time 40.73ms, mfu 11.25%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1850: loss 1.2781, time 40.75ms, mfu 11.30%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1860: loss 1.2507, time 40.60ms, mfu 11.35%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1870: loss 1.1959, time 40.71ms, mfu 11.39%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1880: loss 1.2210, time 40.69ms, mfu 11.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1890: loss 1.2259, time 40.67ms, mfu 11.47%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1900: loss 1.2303, time 40.76ms, mfu 11.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1910: loss 1.2333, time 40.67ms, mfu 11.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1920: loss 1.2288, time 41.09ms, mfu 11.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1930: loss 1.2213, time 40.71ms, mfu 11.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1940: loss 1.2363, time 40.89ms, mfu 11.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1950: loss 1.2344, time 41.03ms, mfu 11.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1960: loss 1.2321, time 40.62ms, mfu 11.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1970: loss 1.2254, time 40.79ms, mfu 11.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1980: loss 1.2283, time 40.67ms, mfu 11.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1990: loss 1.2447, time 40.84ms, mfu 11.66%
# step 2000: train loss 1.1477, val loss 1.4607
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2000: loss 1.2207, time 8790.63ms, mfu 10.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2010: loss 1.2251, time 41.11ms, mfu 10.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2020: loss 1.2078, time 40.63ms, mfu 10.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2030: loss 1.2134, time 41.00ms, mfu 10.83%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2040: loss 1.2103, time 40.43ms, mfu 10.93%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2050: loss 1.2208, time 40.49ms, mfu 11.03%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2060: loss 1.2283, time 40.42ms, mfu 11.11%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2070: loss 1.2020, time 40.97ms, mfu 11.17%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2080: loss 1.2168, time 40.56ms, mfu 11.24%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2090: loss 1.1907, time 40.56ms, mfu 11.29%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2100: loss 1.2018, time 41.08ms, mfu 11.33%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2110: loss 1.2085, time 40.78ms, mfu 11.38%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2120: loss 1.2043, time 41.18ms, mfu 11.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2130: loss 1.1723, time 40.67ms, mfu 11.44%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2140: loss 1.2197, time 40.88ms, mfu 11.47%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2150: loss 1.2255, time 40.65ms, mfu 11.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2160: loss 1.2024, time 40.71ms, mfu 11.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2170: loss 1.2024, time 40.74ms, mfu 11.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2180: loss 1.1831, time 40.72ms, mfu 11.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2190: loss 1.1846, time 40.73ms, mfu 11.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2200: loss 1.1883, time 40.64ms, mfu 11.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2210: loss 1.1962, time 40.95ms, mfu 11.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2220: loss 1.1856, time 40.77ms, mfu 11.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2230: loss 1.1673, time 41.37ms, mfu 11.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2240: loss 1.1937, time 40.70ms, mfu 11.65%
# step 2250: train loss 1.1140, val loss 1.4642
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2250: loss 1.1779, time 8798.56ms, mfu 10.49%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2260: loss 1.2029, time 40.67ms, mfu 10.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2270: loss 1.1963, time 40.70ms, mfu 10.74%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2280: loss 1.1703, time 40.62ms, mfu 10.85%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2290: loss 1.2182, time 41.31ms, mfu 10.92%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2300: loss 1.1985, time 41.17ms, mfu 11.00%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2310: loss 1.1593, time 40.74ms, mfu 11.07%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2320: loss 1.1822, time 40.83ms, mfu 11.14%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2330: loss 1.1951, time 40.70ms, mfu 11.21%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2340: loss 1.1572, time 40.70ms, mfu 11.26%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2350: loss 1.1929, time 40.69ms, mfu 11.32%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2360: loss 1.1863, time 40.79ms, mfu 11.36%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2370: loss 1.1847, time 40.62ms, mfu 11.41%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2380: loss 1.1617, time 40.62ms, mfu 11.45%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2390: loss 1.1765, time 40.75ms, mfu 11.48%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2400: loss 1.1656, time 40.63ms, mfu 11.51%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2410: loss 1.1662, time 41.31ms, mfu 11.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2420: loss 1.1625, time 40.89ms, mfu 11.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2430: loss 1.1729, time 40.85ms, mfu 11.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2440: loss 1.1731, time 40.62ms, mfu 11.59%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2450: loss 1.1571, time 40.75ms, mfu 11.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2460: loss 1.1605, time 40.65ms, mfu 11.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2470: loss 1.1400, time 40.69ms, mfu 11.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2480: loss 1.1573, time 40.93ms, mfu 11.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2490: loss 1.1773, time 40.67ms, mfu 11.66%
# step 2500: train loss 1.0812, val loss 1.4601
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2500: loss 1.1631, time 8810.41ms, mfu 10.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2510: loss 1.1360, time 41.00ms, mfu 10.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2520: loss 1.1357, time 40.96ms, mfu 10.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2530: loss 1.1782, time 40.71ms, mfu 10.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2540: loss 1.1718, time 40.85ms, mfu 10.93%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2550: loss 1.1356, time 40.80ms, mfu 11.01%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2560: loss 1.1812, time 40.94ms, mfu 11.08%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2570: loss 1.1380, time 40.76ms, mfu 11.15%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2580: loss 1.1861, time 41.03ms, mfu 11.20%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2590: loss 1.1244, time 41.46ms, mfu 11.24%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2600: loss 1.1711, time 40.65ms, mfu 11.30%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2610: loss 1.1477, time 40.94ms, mfu 11.34%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2620: loss 1.1578, time 40.68ms, mfu 11.38%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2630: loss 1.1624, time 40.76ms, mfu 11.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2640: loss 1.1258, time 40.69ms, mfu 11.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2650: loss 1.1738, time 41.68ms, mfu 11.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2660: loss 1.1404, time 40.66ms, mfu 11.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2670: loss 1.1340, time 40.74ms, mfu 11.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2680: loss 1.1349, time 40.61ms, mfu 11.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2690: loss 1.1293, time 40.60ms, mfu 11.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2700: loss 1.1434, time 40.87ms, mfu 11.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2710: loss 1.1361, time 40.81ms, mfu 11.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2720: loss 1.1095, time 41.51ms, mfu 11.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2730: loss 1.1773, time 40.62ms, mfu 11.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2740: loss 1.1536, time 42.18ms, mfu 11.60%
# step 2750: train loss 1.0461, val loss 1.4735
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2750: loss 1.1387, time 8788.04ms, mfu 10.45%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2760: loss 1.1062, time 40.68ms, mfu 10.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2770: loss 1.1626, time 40.76ms, mfu 10.70%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2780: loss 1.1517, time 40.74ms, mfu 10.81%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2790: loss 1.1252, time 41.06ms, mfu 10.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2800: loss 1.1250, time 40.71ms, mfu 10.98%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2810: loss 1.1387, time 40.91ms, mfu 11.06%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2820: loss 1.1242, time 40.66ms, mfu 11.13%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2830: loss 1.1334, time 40.77ms, mfu 11.20%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2840: loss 1.1267, time 40.76ms, mfu 11.25%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2850: loss 1.1236, time 40.81ms, mfu 11.30%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2860: loss 1.1624, time 40.74ms, mfu 11.35%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2870: loss 1.1132, time 40.61ms, mfu 11.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2880: loss 1.1247, time 40.81ms, mfu 11.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2890: loss 1.1229, time 42.06ms, mfu 11.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2900: loss 1.1100, time 40.75ms, mfu 11.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2910: loss 1.1311, time 40.48ms, mfu 11.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2920: loss 1.1166, time 41.09ms, mfu 11.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2930: loss 1.1028, time 40.52ms, mfu 11.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2940: loss 1.1341, time 41.62ms, mfu 11.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2950: loss 1.1279, time 40.51ms, mfu 11.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2960: loss 1.1053, time 40.51ms, mfu 11.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2970: loss 1.1109, time 40.55ms, mfu 11.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2980: loss 1.1091, time 40.43ms, mfu 11.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2990: loss 1.1205, time 40.86ms, mfu 11.66%
# step 3000: train loss 1.0177, val loss 1.4601
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3000: loss 1.1230, time 8987.23ms, mfu 10.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3010: loss 1.1173, time 40.69ms, mfu 10.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3020: loss 1.0945, time 41.07ms, mfu 10.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3030: loss 1.1141, time 40.60ms, mfu 10.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3040: loss 1.1067, time 41.91ms, mfu 10.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3050: loss 1.0943, time 40.71ms, mfu 10.99%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3060: loss 1.1103, time 40.56ms, mfu 11.07%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3070: loss 1.1557, time 40.68ms, mfu 11.15%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3080: loss 1.0952, time 40.71ms, mfu 11.21%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3090: loss 1.1009, time 40.59ms, mfu 11.27%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3100: loss 1.1321, time 40.55ms, mfu 11.33%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3110: loss 1.1435, time 40.62ms, mfu 11.38%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3120: loss 1.0920, time 40.39ms, mfu 11.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3130: loss 1.1172, time 40.76ms, mfu 11.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3140: loss 1.0888, time 41.26ms, mfu 11.48%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3150: loss 1.0836, time 41.03ms, mfu 11.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3160: loss 1.1064, time 40.51ms, mfu 11.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3170: loss 1.1128, time 40.59ms, mfu 11.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3180: loss 1.0900, time 40.40ms, mfu 11.59%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3190: loss 1.1001, time 40.81ms, mfu 11.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3200: loss 1.0625, time 40.86ms, mfu 11.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3210: loss 1.0675, time 40.49ms, mfu 11.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3220: loss 1.0711, time 40.39ms, mfu 11.67%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3230: loss 1.0927, time 41.29ms, mfu 11.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3240: loss 1.0964, time 41.12ms, mfu 11.66%
# step 3250: train loss 0.9873, val loss 1.4700
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3250: loss 1.0813, time 8812.37ms, mfu 10.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3260: loss 1.0807, time 40.60ms, mfu 10.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3270: loss 1.1035, time 41.35ms, mfu 10.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3280: loss 1.0859, time 41.27ms, mfu 10.82%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3290: loss 1.1100, time 40.39ms, mfu 10.93%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3300: loss 1.0833, time 40.69ms, mfu 11.01%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3310: loss 1.0757, time 42.00ms, mfu 11.05%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3320: loss 1.0976, time 40.51ms, mfu 11.13%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3330: loss 1.0820, time 40.54ms, mfu 11.20%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3340: loss 1.0861, time 40.70ms, mfu 11.26%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3350: loss 1.0785, time 40.38ms, mfu 11.32%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3360: loss 1.0868, time 41.17ms, mfu 11.36%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3370: loss 1.0624, time 40.43ms, mfu 11.41%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3380: loss 1.1072, time 40.46ms, mfu 11.45%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3390: loss 1.0676, time 40.75ms, mfu 11.48%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3400: loss 1.0592, time 40.45ms, mfu 11.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3410: loss 1.0777, time 41.03ms, mfu 11.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3420: loss 1.0758, time 41.01ms, mfu 11.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3430: loss 1.0882, time 40.53ms, mfu 11.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3440: loss 1.0981, time 41.71ms, mfu 11.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3450: loss 1.0928, time 40.50ms, mfu 11.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3460: loss 1.0737, time 40.49ms, mfu 11.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3470: loss 1.0592, time 40.54ms, mfu 11.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3480: loss 1.0777, time 40.49ms, mfu 11.67%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3490: loss 1.0771, time 40.36ms, mfu 11.69%
# step 3500: train loss 0.9623, val loss 1.4720
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3500: loss 1.0438, time 8814.56ms, mfu 10.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3510: loss 1.0767, time 40.46ms, mfu 10.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3520: loss 1.0816, time 40.93ms, mfu 10.76%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3530: loss 1.0583, time 40.96ms, mfu 10.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3540: loss 1.0683, time 40.68ms, mfu 10.95%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3550: loss 1.0642, time 40.49ms, mfu 11.04%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3560: loss 1.0733, time 41.14ms, mfu 11.10%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3570: loss 1.0667, time 41.50ms, mfu 11.15%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3580: loss 1.0385, time 40.84ms, mfu 11.21%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3590: loss 1.0578, time 40.42ms, mfu 11.28%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3600: loss 1.0578, time 40.57ms, mfu 11.33%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3610: loss 1.0623, time 41.06ms, mfu 11.37%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3620: loss 1.0395, time 40.60ms, mfu 11.41%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3630: loss 1.0593, time 40.64ms, mfu 11.45%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3640: loss 1.0527, time 41.09ms, mfu 11.47%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3650: loss 1.0439, time 41.15ms, mfu 11.49%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3660: loss 1.0516, time 40.54ms, mfu 11.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3670: loss 1.0832, time 40.87ms, mfu 11.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3680: loss 1.0637, time 40.63ms, mfu 11.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3690: loss 1.0522, time 40.58ms, mfu 11.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3700: loss 1.0679, time 40.79ms, mfu 11.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# ...
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3890: loss 1.0385, time 40.88ms, mfu 11.48%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3900: loss 1.0326, time 40.54ms, mfu 11.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3910: loss 1.0092, time 40.76ms, mfu 11.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3920: loss 1.0274, time 40.90ms, mfu 11.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3930: loss 1.0047, time 40.66ms, mfu 11.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3940: loss 1.0530, time 40.79ms, mfu 11.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3950: loss 1.0279, time 40.75ms, mfu 11.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3960: loss 1.0559, time 40.72ms, mfu 11.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3970: loss 1.0259, time 40.73ms, mfu 11.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3980: loss 1.0446, time 40.97ms, mfu 11.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3990: loss 1.0063, time 40.92ms, mfu 11.66%
# step 4000: train loss 0.9176, val loss 1.4943
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4000: loss 1.0345, time 8881.38ms, mfu 10.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4010: loss 1.0514, time 40.76ms, mfu 10.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4020: loss 1.0345, time 40.71ms, mfu 10.74%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4030: loss 1.0187, time 40.81ms, mfu 10.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4040: loss 1.0396, time 40.65ms, mfu 10.94%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4050: loss 1.0372, time 40.58ms, mfu 11.03%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4060: loss 1.0339, time 40.44ms, mfu 11.11%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4070: loss 1.0104, time 40.90ms, mfu 11.17%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4080: loss 1.0069, time 40.87ms, mfu 11.23%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4090: loss 1.0089, time 41.06ms, mfu 11.28%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4100: loss 1.0469, time 40.71ms, mfu 11.33%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4110: loss 1.0057, time 41.18ms, mfu 11.36%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4120: loss 1.0325, time 40.78ms, mfu 11.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4130: loss 1.0066, time 40.84ms, mfu 11.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4140: loss 1.0125, time 40.69ms, mfu 11.47%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4150: loss 1.0156, time 40.82ms, mfu 11.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4160: loss 1.0467, time 40.72ms, mfu 11.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4170: loss 1.0279, time 40.84ms, mfu 11.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4180: loss 1.0300, time 40.67ms, mfu 11.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4190: loss 1.0088, time 40.87ms, mfu 11.59%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4200: loss 1.0102, time 41.09ms, mfu 11.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4210: loss 1.0294, time 41.31ms, mfu 11.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4220: loss 1.0044, time 40.94ms, mfu 11.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4230: loss 1.0143, time 40.54ms, mfu 11.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4240: loss 1.0030, time 40.76ms, mfu 11.65%
# step 4250: train loss 0.8990, val loss 1.4977
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4250: loss 1.0293, time 8741.56ms, mfu 10.49%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4260: loss 1.0414, time 41.01ms, mfu 10.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4270: loss 1.0359, time 40.40ms, mfu 10.74%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4280: loss 1.0296, time 41.33ms, mfu 10.82%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4290: loss 1.0347, time 41.44ms, mfu 10.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4300: loss 1.0145, time 40.52ms, mfu 10.99%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4310: loss 1.0205, time 41.05ms, mfu 11.06%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4320: loss 0.9958, time 41.32ms, mfu 11.12%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4330: loss 1.0122, time 41.24ms, mfu 11.17%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4340: loss 1.0041, time 40.78ms, mfu 11.23%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4350: loss 1.0300, time 40.79ms, mfu 11.28%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4360: loss 0.9897, time 40.63ms, mfu 11.33%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4370: loss 1.0168, time 41.14ms, mfu 11.37%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4380: loss 1.0057, time 40.37ms, mfu 11.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4390: loss 1.0172, time 41.83ms, mfu 11.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4400: loss 1.0150, time 41.84ms, mfu 11.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4410: loss 1.0152, time 42.33ms, mfu 11.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4420: loss 1.0112, time 40.48ms, mfu 11.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4430: loss 0.9981, time 42.77ms, mfu 11.44%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4440: loss 0.9923, time 42.43ms, mfu 11.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4450: loss 1.0070, time 41.87ms, mfu 11.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4460: loss 1.0234, time 42.60ms, mfu 11.41%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4470: loss 1.0123, time 42.31ms, mfu 11.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4480: loss 1.0188, time 41.09ms, mfu 11.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4490: loss 1.0150, time 42.31ms, mfu 11.42%
# step 4500: train loss 0.8833, val loss 1.5127
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4500: loss 1.0135, time 8754.30ms, mfu 10.28%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4510: loss 1.0019, time 40.82ms, mfu 10.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4520: loss 1.0110, time 42.00ms, mfu 10.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4530: loss 1.0203, time 41.58ms, mfu 10.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4540: loss 0.9990, time 42.90ms, mfu 10.69%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4550: loss 1.0043, time 40.34ms, mfu 10.81%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4560: loss 1.0189, time 41.57ms, mfu 10.88%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4570: loss 1.0226, time 42.26ms, mfu 10.93%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4580: loss 1.0261, time 42.51ms, mfu 10.96%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4590: loss 0.9701, time 40.97ms, mfu 11.04%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4600: loss 0.9939, time 42.16ms, mfu 11.07%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4610: loss 1.0103, time 40.41ms, mfu 11.15%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4620: loss 0.9872, time 41.71ms, mfu 11.19%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4630: loss 0.9849, time 40.93ms, mfu 11.24%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4640: loss 1.0238, time 42.42ms, mfu 11.25%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4650: loss 0.9905, time 41.58ms, mfu 11.28%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4660: loss 1.0090, time 41.87ms, mfu 11.29%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4670: loss 0.9941, time 41.62ms, mfu 11.32%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4680: loss 1.0155, time 41.35ms, mfu 11.35%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4690: loss 0.9714, time 42.64ms, mfu 11.34%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4700: loss 1.0318, time 42.70ms, mfu 11.33%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4710: loss 1.0008, time 41.83ms, mfu 11.34%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4720: loss 1.0151, time 42.43ms, mfu 11.34%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4730: loss 0.9888, time 42.30ms, mfu 11.34%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4740: loss 0.9871, time 40.34ms, mfu 11.39%
# step 4750: train loss 0.8689, val loss 1.5089
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4750: loss 0.9887, time 8758.23ms, mfu 10.26%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4760: loss 1.0073, time 40.43ms, mfu 10.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4770: loss 1.0005, time 41.61ms, mfu 10.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4780: loss 0.9856, time 41.52ms, mfu 10.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4790: loss 1.0033, time 42.05ms, mfu 10.71%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4800: loss 0.9914, time 42.48ms, mfu 10.77%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4810: loss 1.0020, time 40.65ms, mfu 10.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4820: loss 0.9630, time 42.29ms, mfu 10.92%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4830: loss 0.9981, time 41.14ms, mfu 10.99%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4840: loss 0.9983, time 40.78ms, mfu 11.07%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4850: loss 0.9973, time 41.97ms, mfu 11.11%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4860: loss 1.0283, time 42.06ms, mfu 11.14%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4870: loss 1.0069, time 41.24ms, mfu 11.19%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4880: loss 0.9902, time 42.27ms, mfu 11.20%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4890: loss 0.9956, time 40.38ms, mfu 11.27%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4900: loss 1.0032, time 41.70ms, mfu 11.29%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4910: loss 0.9870, time 41.58ms, mfu 11.32%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4920: loss 0.9747, time 40.98ms, mfu 11.36%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4930: loss 0.9924, time 40.83ms, mfu 11.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4940: loss 0.9942, time 40.66ms, mfu 11.44%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4950: loss 0.9873, time 40.83ms, mfu 11.47%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4960: loss 0.9870, time 40.57ms, mfu 11.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4970: loss 1.0089, time 40.60ms, mfu 11.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4980: loss 0.9924, time 40.56ms, mfu 11.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4990: loss 0.9929, time 40.48ms, mfu 11.59%
# step 5000: train loss 0.8614, val loss 1.5192
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 5000: loss 0.9803, time 8828.53ms, mfu 10.44%
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# VBox(children=(Label(value='0.299 MB of 0.299 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iter</td><td>▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>lr</td><td>▁████▇▇▆▆▅▅▄▄▃▃▃▂▂▂▂▂</td></tr><tr><td>mfu</td><td>▁████████████████████</td></tr><tr><td>test/loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>█▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iter</td><td>5000</td></tr><tr><td>lr</td><td>0.0001</td></tr><tr><td>mfu</td><td>11.59282</td></tr><tr><td>test/loss</td><td>1.5835</td></tr><tr><td>train/loss</td><td>0.86139</td></tr><tr><td>val/loss</td><td>1.51915</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">AbstractTransformerLM (Positional Symbols</strong> at: <a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/1rqt61ns' target="_blank">https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/1rqt61ns</a><br/>Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20240118_190436-1rqt61ns/logs</code>
# DONE.

# %% [markdown]
# ## Abstract Transformer Model (Symbolic Attention)

# %%
model_args = dict(
    vocab_size=vocab_size, d_model=384, n_layers=6, n_heads_enc=4, n_heads_abs=2, dff=None,
    symbol_retrieval='symbolic_attention', symbol_retrieval_kwargs=dict(num_symbols=50, n_heads=4, model_dim=384), # FIXME make names consistent: d_model, model_dim
    dropout_rate=0.2, activation='relu', norm_first=True, max_block_size=256, bias=True)
model = abstracttransformer_lm = AbstractTransformerLM(**model_args).to(device)

# %%
torchinfo.summary(model, input_data=torch.randint(0, 10, size=(1,256)), device='cuda')
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# AbstractTransformerLM                         [1, 1, 65]                --
# ├─ModuleDict: 1-1                             --                        --
# │    └─Embedding: 2-1                         [1, 256, 384]             24,960
# │    └─Embedding: 2-2                         [256, 384]                98,304
# │    └─ModuleList: 2-3                        --                        --
# │    │    └─AbstractEncoderBlock: 3-1         [1, 256, 384]             2,404,224
# │    │    └─AbstractEncoderBlock: 3-14        --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-3         --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-4         [1, 256, 384]             2,404,224
# │    │    └─AbstractEncoderBlock: 3-14        --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-6         --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-7         [1, 256, 384]             2,404,224
# │    │    └─AbstractEncoderBlock: 3-14        --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-9         --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-10        [1, 256, 384]             2,404,224
# │    │    └─AbstractEncoderBlock: 3-14        --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-12        --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-13        [1, 256, 384]             2,404,224
# │    │    └─AbstractEncoderBlock: 3-14        --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-15        --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-16        [1, 256, 384]             2,404,224
# │    └─Linear: 2-4                            [1, 1, 65]                25,025
# ===============================================================================================
# Total params: 25,845,953
# Trainable params: 25,845,953
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 33.20
# ===============================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 39.32
# Params size (MB): 29.58
# Estimated Total Size (MB): 68.90
# ===============================================================================================

# %%
# torchinfo overcounts # of params... something to do with symbolic attention shared across layers
# this is the correct number (similar to TransformerLM)

num_params = model.get_num_params() #sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'# of params {num_params:,}')
# Out:
# # of params 13,544,129

# %%
# TODO: can we implement in a way that torchinfo can understand? i.e., without "recursive" and overcounting

# %% [markdown]
# ### Training

# %%
# grad scaler
scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16'))
# optimizer
optimizer = configure_optimizers(model, weight_decay, learning_rate, (beta1, beta2), device_type=device)
# Out:
# num decayed parameter tensors: 42, with 13,605,120 parameters
# num non-decayed parameter tensors: 62, with 37,313 parameters
# using fused AdamW: True

# %%
def get_lr(it):
    # 1) linear warmup for warmup_iters steps
    if it < warmup_iters:
        return learning_rate * it / warmup_iters
    # 2) if it > lr_decay_iters, return min learning rate
    if it > lr_decay_iters:
        return min_lr
    # 3) in between, use cosine decay down to min learning rate
    decay_ratio = (it - warmup_iters) / (lr_decay_iters - warmup_iters)
    assert 0 <= decay_ratio <= 1
    coeff = 0.5 * (1.0 + math.cos(math.pi * decay_ratio)) # coeff ranges 0..1
    return min_lr + coeff * (learning_rate - min_lr)

# %%
@torch.no_grad()
def eval_model(model, ctx=None):

    ctx = nullcontext() if ctx is None else ctx
    out = {}
    model.eval()
    for split in ['train', 'val', 'test']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            with ctx:
                logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[f'{split}/loss'] = losses.mean()
    model.train()
    return out

# %%
train_kwargs = dict(
    model=model, get_batch=get_batch, batch_size=batch_size, max_iters=max_iters,
    optimizer=optimizer, scaler=scaler, get_lr=get_lr, eval_model=eval_model,
    compile=True, grad_clip=0, gradient_accumulation_steps=gradient_accumulation_steps,
    eval_main_metric='val/loss', eval_interval=eval_interval, always_save_checkpoint=always_save_checkpoint, out_dir=out_dir,
    log_interval=10, wandb_log=True, wandb_init_kwargs=dict(project=wandb_project, name='AbstractTransformerLM (Symbolic Attn)'), 
    ckpt_dict=dict(model_args=model_args), track_mfu=True,
    master_process=True, ddp=False, device_type='cuda')

# %%
train_model(**train_kwargs)
# Out:
# Tracking run with wandb version 0.16.2
# Run data is saved locally in <code>/gpfs/gibbs/project/lafferty/ma2393/abstract_transformer/experiments/wandb/run-20240118_181223-spj237be</code>
# Syncing run <strong><a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/spj237be' target="_blank">AbstractTransformerLM</a></strong> to <a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char' target="_blank">https://wandb.ai/awni00/abstract_transformer--shakespeare_char</a>
#  View run at <a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/spj237be' target="_blank">https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/spj237be</a>
# compiling model... done compiling.
# starting training loop...
# step 0: train loss 4.5138, val loss 4.5241
# iter 0: loss 4.5282, time 38968.17ms, mfu -100.00%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 10: loss 3.5001, time 45.92ms, mfu 10.51%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 20: loss 3.0401, time 44.71ms, mfu 10.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 30: loss 2.8042, time 44.64ms, mfu 10.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 40: loss 2.6757, time 44.29ms, mfu 10.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 50: loss 2.5827, time 44.33ms, mfu 10.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 60: loss 2.5442, time 44.46ms, mfu 10.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 70: loss 2.5184, time 44.56ms, mfu 10.67%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 80: loss 2.5417, time 44.55ms, mfu 10.68%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 90: loss 2.5092, time 44.52ms, mfu 10.70%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 100: loss 2.5176, time 44.57ms, mfu 10.71%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 110: loss 2.4853, time 44.38ms, mfu 10.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 120: loss 2.4697, time 44.47ms, mfu 10.74%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 130: loss 2.4463, time 45.71ms, mfu 10.72%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 140: loss 2.4223, time 44.45ms, mfu 10.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 150: loss 2.3991, time 44.42ms, mfu 10.75%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 160: loss 2.3682, time 44.38ms, mfu 10.76%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 170: loss 2.3177, time 44.65ms, mfu 10.76%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 180: loss 2.2865, time 44.49ms, mfu 10.77%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 190: loss 2.1733, time 44.45ms, mfu 10.78%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 200: loss 2.1444, time 44.56ms, mfu 10.79%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 210: loss 2.0991, time 44.77ms, mfu 10.78%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 220: loss 2.0386, time 44.47ms, mfu 10.79%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 230: loss 2.0249, time 44.49ms, mfu 10.80%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 240: loss 1.9749, time 45.60ms, mfu 10.77%
# step 250: train loss 1.8914, val loss 1.9815
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 250: loss 1.9414, time 9924.49ms, mfu 9.70%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 260: loss 1.9142, time 44.23ms, mfu 9.82%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 270: loss 1.9466, time 44.42ms, mfu 9.93%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 280: loss 1.8935, time 44.50ms, mfu 10.02%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 290: loss 1.8563, time 44.40ms, mfu 10.10%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 300: loss 1.8371, time 44.48ms, mfu 10.18%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 310: loss 1.8154, time 44.54ms, mfu 10.24%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 320: loss 1.7651, time 44.37ms, mfu 10.31%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 330: loss 1.7707, time 44.42ms, mfu 10.36%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 340: loss 1.7785, time 44.49ms, mfu 10.41%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 350: loss 1.7514, time 44.43ms, mfu 10.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 360: loss 1.7237, time 44.56ms, mfu 10.49%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 370: loss 1.7320, time 44.43ms, mfu 10.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 380: loss 1.7109, time 44.39ms, mfu 10.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 390: loss 1.6884, time 44.35ms, mfu 10.59%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 400: loss 1.7195, time 44.45ms, mfu 10.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 410: loss 1.6881, time 44.66ms, mfu 10.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 420: loss 1.6616, time 44.57ms, mfu 10.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 430: loss 1.6395, time 44.37ms, mfu 10.68%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 440: loss 1.6685, time 44.31ms, mfu 10.70%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 450: loss 1.6418, time 44.52ms, mfu 10.71%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 460: loss 1.6214, time 44.34ms, mfu 10.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 470: loss 1.6374, time 44.50ms, mfu 10.74%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 480: loss 1.6224, time 44.65ms, mfu 10.75%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 490: loss 1.5905, time 44.69ms, mfu 10.75%
# step 500: train loss 1.5186, val loss 1.7016
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 500: loss 1.5923, time 10002.95ms, mfu 9.68%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 510: loss 1.5970, time 44.62ms, mfu 9.80%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 520: loss 1.5909, time 44.50ms, mfu 9.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 530: loss 1.5806, time 44.80ms, mfu 9.99%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 540: loss 1.5810, time 44.66ms, mfu 10.07%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 550: loss 1.5576, time 44.56ms, mfu 10.14%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 560: loss 1.5577, time 44.67ms, mfu 10.21%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 570: loss 1.5236, time 44.74ms, mfu 10.27%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 580: loss 1.5591, time 45.90ms, mfu 10.29%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 590: loss 1.5546, time 44.68ms, mfu 10.34%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 600: loss 1.5451, time 44.42ms, mfu 10.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 610: loss 1.5483, time 44.57ms, mfu 10.44%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 620: loss 1.5053, time 44.62ms, mfu 10.48%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 630: loss 1.5146, time 44.52ms, mfu 10.51%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 640: loss 1.4637, time 43.95ms, mfu 10.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 650: loss 1.5170, time 46.84ms, mfu 10.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 660: loss 1.4728, time 44.86ms, mfu 10.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 670: loss 1.4654, time 48.06ms, mfu 10.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 680: loss 1.4678, time 45.03ms, mfu 10.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 690: loss 1.4575, time 45.32ms, mfu 10.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 700: loss 1.4830, time 45.51ms, mfu 10.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 710: loss 1.4683, time 45.34ms, mfu 10.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 720: loss 1.4513, time 45.34ms, mfu 10.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 730: loss 1.4679, time 45.18ms, mfu 10.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 740: loss 1.4837, time 45.35ms, mfu 10.58%
# step 750: train loss 1.3914, val loss 1.5870
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 750: loss 1.4647, time 10040.67ms, mfu 9.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 760: loss 1.4590, time 44.81ms, mfu 9.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 770: loss 1.4614, time 44.73ms, mfu 9.76%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 780: loss 1.4457, time 44.90ms, mfu 9.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 790: loss 1.4386, time 47.80ms, mfu 9.89%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 800: loss 1.4293, time 46.05ms, mfu 9.95%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 810: loss 1.4660, time 45.21ms, mfu 10.02%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 820: loss 1.4121, time 45.30ms, mfu 10.08%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 830: loss 1.4231, time 45.09ms, mfu 10.14%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 840: loss 1.4328, time 45.02ms, mfu 10.20%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 850: loss 1.4255, time 45.08ms, mfu 10.25%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 860: loss 1.4307, time 45.20ms, mfu 10.29%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 870: loss 1.4417, time 45.37ms, mfu 10.33%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 880: loss 1.3889, time 45.08ms, mfu 10.36%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 890: loss 1.3916, time 46.83ms, mfu 10.36%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 900: loss 1.4370, time 44.71ms, mfu 10.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 910: loss 1.4128, time 45.72ms, mfu 10.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 920: loss 1.3763, time 44.34ms, mfu 10.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 930: loss 1.3763, time 44.47ms, mfu 10.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 940: loss 1.3962, time 44.41ms, mfu 10.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 950: loss 1.4046, time 44.45ms, mfu 10.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 960: loss 1.3771, time 44.45ms, mfu 10.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 970: loss 1.3882, time 44.50ms, mfu 10.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 980: loss 1.4085, time 44.57ms, mfu 10.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 990: loss 1.3774, time 44.61ms, mfu 10.66%
# step 1000: train loss 1.3065, val loss 1.5347
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1000: loss 1.4070, time 10085.68ms, mfu 9.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1010: loss 1.3769, time 45.50ms, mfu 9.70%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1020: loss 1.4213, time 44.97ms, mfu 9.80%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1030: loss 1.3603, time 44.93ms, mfu 9.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1040: loss 1.4042, time 44.85ms, mfu 9.98%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1050: loss 1.3595, time 44.77ms, mfu 10.06%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1060: loss 1.3184, time 44.79ms, mfu 10.13%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1070: loss 1.3667, time 44.75ms, mfu 10.20%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1080: loss 1.3723, time 44.74ms, mfu 10.26%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1090: loss 1.3626, time 44.73ms, mfu 10.31%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1100: loss 1.3546, time 44.84ms, mfu 10.35%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1110: loss 1.3341, time 44.81ms, mfu 10.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1120: loss 1.3432, time 45.14ms, mfu 10.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1130: loss 1.3421, time 44.93ms, mfu 10.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1140: loss 1.3624, time 44.72ms, mfu 10.49%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1150: loss 1.3449, time 44.74ms, mfu 10.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1160: loss 1.3697, time 44.85ms, mfu 10.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1170: loss 1.3455, time 44.59ms, mfu 10.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1180: loss 1.3303, time 44.57ms, mfu 10.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1190: loss 1.3601, time 45.30ms, mfu 10.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1200: loss 1.3507, time 44.61ms, mfu 10.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1210: loss 1.3256, time 45.81ms, mfu 10.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1220: loss 1.3284, time 47.19ms, mfu 10.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1230: loss 1.3046, time 45.75ms, mfu 10.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1240: loss 1.3193, time 46.16ms, mfu 10.56%
# step 1250: train loss 1.2470, val loss 1.4936
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1250: loss 1.3086, time 10043.49ms, mfu 9.51%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1260: loss 1.3006, time 44.78ms, mfu 9.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1270: loss 1.3141, time 44.76ms, mfu 9.75%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1280: loss 1.3052, time 44.35ms, mfu 9.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1290: loss 1.3122, time 44.64ms, mfu 9.96%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1300: loss 1.3457, time 44.45ms, mfu 10.05%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1310: loss 1.3148, time 44.98ms, mfu 10.12%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1320: loss 1.3026, time 47.61ms, mfu 10.12%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1330: loss 1.3040, time 45.28ms, mfu 10.17%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1340: loss 1.2797, time 45.37ms, mfu 10.22%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1350: loss 1.2928, time 45.48ms, mfu 10.26%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1360: loss 1.2640, time 45.13ms, mfu 10.30%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1370: loss 1.2982, time 45.49ms, mfu 10.33%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1380: loss 1.3220, time 45.43ms, mfu 10.36%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1390: loss 1.3244, time 45.54ms, mfu 10.38%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1400: loss 1.2549, time 45.01ms, mfu 10.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1410: loss 1.2900, time 45.06ms, mfu 10.45%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1420: loss 1.3074, time 46.82ms, mfu 10.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1430: loss 1.2848, time 44.88ms, mfu 10.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1440: loss 1.2739, time 44.80ms, mfu 10.49%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1450: loss 1.2939, time 44.65ms, mfu 10.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1460: loss 1.2791, time 45.13ms, mfu 10.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1470: loss 1.2787, time 44.98ms, mfu 10.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1480: loss 1.2705, time 44.92ms, mfu 10.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1490: loss 1.2823, time 44.64ms, mfu 10.60%
# step 1500: train loss 1.2041, val loss 1.4727
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1500: loss 1.2829, time 10082.13ms, mfu 9.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1510: loss 1.2551, time 45.10ms, mfu 9.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1520: loss 1.2830, time 45.10ms, mfu 9.76%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1530: loss 1.2658, time 44.74ms, mfu 9.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1540: loss 1.2943, time 45.62ms, mfu 9.94%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1550: loss 1.2781, time 44.59ms, mfu 10.03%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1560: loss 1.2819, time 44.55ms, mfu 10.11%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1570: loss 1.2626, time 44.60ms, mfu 10.18%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1580: loss 1.2342, time 44.50ms, mfu 10.24%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1590: loss 1.2618, time 44.65ms, mfu 10.30%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1600: loss 1.2213, time 44.59ms, mfu 10.35%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1610: loss 1.2563, time 44.58ms, mfu 10.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1620: loss 1.2646, time 44.44ms, mfu 10.45%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1630: loss 1.2626, time 44.58ms, mfu 10.48%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1640: loss 1.2611, time 44.71ms, mfu 10.51%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1650: loss 1.2348, time 44.75ms, mfu 10.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1660: loss 1.2509, time 44.42ms, mfu 10.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1670: loss 1.2422, time 44.59ms, mfu 10.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1680: loss 1.2443, time 44.56ms, mfu 10.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1690: loss 1.2479, time 44.57ms, mfu 10.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1700: loss 1.2403, time 44.61ms, mfu 10.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1710: loss 1.2358, time 45.42ms, mfu 10.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1720: loss 1.2472, time 45.11ms, mfu 10.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1730: loss 1.2703, time 46.97ms, mfu 10.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1740: loss 1.2392, time 45.31ms, mfu 10.62%
# step 1750: train loss 1.1600, val loss 1.4713
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1750: loss 1.2309, time 10081.74ms, mfu 9.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1760: loss 1.2481, time 44.83ms, mfu 9.69%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1770: loss 1.2235, time 44.77ms, mfu 9.79%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1780: loss 1.2524, time 44.85ms, mfu 9.89%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1790: loss 1.2425, time 44.84ms, mfu 9.98%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1800: loss 1.2349, time 44.84ms, mfu 10.06%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1810: loss 1.2185, time 44.86ms, mfu 10.13%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1820: loss 1.2236, time 44.61ms, mfu 10.19%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1830: loss 1.2191, time 44.56ms, mfu 10.26%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1840: loss 1.2366, time 44.68ms, mfu 10.31%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1850: loss 1.2309, time 44.73ms, mfu 10.36%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1860: loss 1.2367, time 44.97ms, mfu 10.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1870: loss 1.2030, time 47.13ms, mfu 10.38%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1880: loss 1.2222, time 45.08ms, mfu 10.41%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1890: loss 1.2040, time 44.89ms, mfu 10.45%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1900: loss 1.2225, time 45.10ms, mfu 10.47%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1910: loss 1.2173, time 44.59ms, mfu 10.51%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1920: loss 1.1960, time 44.85ms, mfu 10.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1930: loss 1.2052, time 44.66ms, mfu 10.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1940: loss 1.2285, time 44.75ms, mfu 10.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1950: loss 1.2093, time 44.66ms, mfu 10.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1960: loss 1.1952, time 45.45ms, mfu 10.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1970: loss 1.2316, time 44.76ms, mfu 10.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1980: loss 1.1999, time 44.73ms, mfu 10.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1990: loss 1.2077, time 44.39ms, mfu 10.66%
# step 2000: train loss 1.1191, val loss 1.4607
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2000: loss 1.2032, time 9987.86ms, mfu 9.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2010: loss 1.2265, time 44.87ms, mfu 9.72%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2020: loss 1.1945, time 45.23ms, mfu 9.81%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2030: loss 1.1888, time 45.42ms, mfu 9.89%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2040: loss 1.1925, time 45.32ms, mfu 9.97%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2050: loss 1.1912, time 45.10ms, mfu 10.04%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2060: loss 1.2120, time 44.69ms, mfu 10.12%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2070: loss 1.1972, time 45.17ms, mfu 10.17%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2080: loss 1.2132, time 44.74ms, mfu 10.23%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2090: loss 1.1639, time 46.74ms, mfu 10.24%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2100: loss 1.2331, time 44.83ms, mfu 10.29%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2110: loss 1.1734, time 44.53ms, mfu 10.35%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2120: loss 1.1805, time 44.80ms, mfu 10.39%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2130: loss 1.2121, time 44.56ms, mfu 10.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2140: loss 1.1703, time 44.51ms, mfu 10.48%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2150: loss 1.1841, time 44.64ms, mfu 10.51%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2160: loss 1.1415, time 44.74ms, mfu 10.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2170: loss 1.1934, time 44.74ms, mfu 10.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2180: loss 1.1636, time 44.70ms, mfu 10.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2190: loss 1.2038, time 44.76ms, mfu 10.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2200: loss 1.1841, time 44.89ms, mfu 10.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2210: loss 1.1654, time 44.67ms, mfu 10.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2220: loss 1.1672, time 44.70ms, mfu 10.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2230: loss 1.1560, time 44.82ms, mfu 10.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2240: loss 1.1546, time 44.74ms, mfu 10.68%
# step 2250: train loss 1.0828, val loss 1.4672
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2250: loss 1.1711, time 9897.42ms, mfu 9.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2260: loss 1.1616, time 44.70ms, mfu 9.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2270: loss 1.1665, time 44.47ms, mfu 9.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2280: loss 1.1594, time 44.63ms, mfu 9.94%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2290: loss 1.1512, time 44.58ms, mfu 10.03%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2300: loss 1.1677, time 44.67ms, mfu 10.11%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2310: loss 1.1325, time 44.64ms, mfu 10.18%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2320: loss 1.1432, time 44.53ms, mfu 10.24%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2330: loss 1.1566, time 44.71ms, mfu 10.30%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2340: loss 1.1744, time 44.67ms, mfu 10.35%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2350: loss 1.1548, time 45.41ms, mfu 10.37%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2360: loss 1.1639, time 44.71ms, mfu 10.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2370: loss 1.1678, time 44.82ms, mfu 10.45%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2380: loss 1.1485, time 44.50ms, mfu 10.49%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2390: loss 1.1878, time 44.52ms, mfu 10.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2400: loss 1.1476, time 44.38ms, mfu 10.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2410: loss 1.1425, time 46.93ms, mfu 10.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2420: loss 1.1421, time 44.88ms, mfu 10.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2430: loss 1.1417, time 46.29ms, mfu 10.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2440: loss 1.1406, time 45.21ms, mfu 10.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2450: loss 1.1430, time 45.24ms, mfu 10.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2460: loss 1.1507, time 45.92ms, mfu 10.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2470: loss 1.1513, time 45.53ms, mfu 10.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2480: loss 1.1353, time 45.15ms, mfu 10.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2490: loss 1.1252, time 45.41ms, mfu 10.58%
# step 2500: train loss 1.0441, val loss 1.4638
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2500: loss 1.1286, time 9858.66ms, mfu 9.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2510: loss 1.1513, time 44.59ms, mfu 9.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2520: loss 1.1343, time 44.58ms, mfu 9.77%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2530: loss 1.1409, time 44.73ms, mfu 9.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2540: loss 1.1205, time 45.04ms, mfu 9.96%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2550: loss 1.1120, time 44.64ms, mfu 10.04%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2560: loss 1.1498, time 44.97ms, mfu 10.11%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2570: loss 1.0992, time 45.06ms, mfu 10.17%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2580: loss 1.1500, time 45.04ms, mfu 10.23%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2590: loss 1.1460, time 45.01ms, mfu 10.28%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2600: loss 1.0970, time 45.06ms, mfu 10.32%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2610: loss 1.1111, time 45.20ms, mfu 10.35%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2620: loss 1.1153, time 45.19ms, mfu 10.39%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2630: loss 1.1098, time 44.82ms, mfu 10.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2640: loss 1.1243, time 45.01ms, mfu 10.45%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2650: loss 1.1133, time 44.93ms, mfu 10.48%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2660: loss 1.1298, time 47.02ms, mfu 10.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2670: loss 1.1110, time 44.77ms, mfu 10.49%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2680: loss 1.1194, time 44.73ms, mfu 10.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2690: loss 1.0785, time 44.68ms, mfu 10.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2700: loss 1.1041, time 44.63ms, mfu 10.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2710: loss 1.1107, time 44.52ms, mfu 10.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2720: loss 1.1249, time 44.74ms, mfu 10.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2730: loss 1.1174, time 44.72ms, mfu 10.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2740: loss 1.1149, time 44.74ms, mfu 10.65%
# step 2750: train loss 1.0090, val loss 1.4545
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2750: loss 1.0836, time 10072.94ms, mfu 9.59%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2760: loss 1.1107, time 44.93ms, mfu 9.71%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2770: loss 1.1339, time 44.83ms, mfu 9.81%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2780: loss 1.1201, time 44.65ms, mfu 9.91%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2790: loss 1.0904, time 44.66ms, mfu 10.00%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2800: loss 1.0934, time 45.37ms, mfu 10.06%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2810: loss 1.0931, time 44.87ms, mfu 10.13%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2820: loss 1.1154, time 44.99ms, mfu 10.19%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2830: loss 1.0967, time 44.71ms, mfu 10.25%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2840: loss 1.0706, time 44.70ms, mfu 10.31%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2850: loss 1.1127, time 44.86ms, mfu 10.35%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2860: loss 1.1028, time 44.78ms, mfu 10.39%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2870: loss 1.0963, time 44.84ms, mfu 10.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2880: loss 1.0738, time 44.52ms, mfu 10.47%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2890: loss 1.1065, time 44.91ms, mfu 10.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2900: loss 1.0969, time 44.75ms, mfu 10.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2910: loss 1.0901, time 45.01ms, mfu 10.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2920: loss 1.1137, time 44.98ms, mfu 10.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2930: loss 1.0937, time 44.94ms, mfu 10.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2940: loss 1.1046, time 44.58ms, mfu 10.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2950: loss 1.1186, time 44.57ms, mfu 10.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2960: loss 1.0818, time 44.59ms, mfu 10.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2970: loss 1.0692, time 44.84ms, mfu 10.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2980: loss 1.0813, time 45.02ms, mfu 10.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2990: loss 1.0927, time 47.94ms, mfu 10.60%
# step 3000: train loss 0.9781, val loss 1.4632
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3000: loss 1.0738, time 9857.30ms, mfu 9.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3010: loss 1.0785, time 44.46ms, mfu 9.68%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3020: loss 1.1076, time 44.56ms, mfu 9.79%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3030: loss 1.1014, time 44.43ms, mfu 9.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3040: loss 1.0629, time 45.50ms, mfu 9.97%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3050: loss 1.0542, time 44.61ms, mfu 10.06%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3060: loss 1.0779, time 44.81ms, mfu 10.13%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3070: loss 1.0779, time 47.66ms, mfu 10.13%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3080: loss 1.0841, time 44.87ms, mfu 10.19%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3090: loss 1.0499, time 45.37ms, mfu 10.23%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3100: loss 1.0881, time 45.58ms, mfu 10.27%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3110: loss 1.0783, time 45.12ms, mfu 10.31%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3120: loss 1.0851, time 45.52ms, mfu 10.34%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3130: loss 1.0788, time 45.56ms, mfu 10.37%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3140: loss 1.0840, time 45.27ms, mfu 10.39%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3150: loss 1.0795, time 45.39ms, mfu 10.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3160: loss 1.0683, time 45.67ms, mfu 10.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3170: loss 1.0608, time 45.25ms, mfu 10.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3180: loss 1.0660, time 45.26ms, mfu 10.48%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3190: loss 1.0344, time 46.64ms, mfu 10.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3200: loss 1.0733, time 44.68ms, mfu 10.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3210: loss 1.0598, time 45.04ms, mfu 10.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3220: loss 1.0427, time 44.50ms, mfu 10.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3230: loss 1.0606, time 44.58ms, mfu 10.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3240: loss 1.0716, time 44.93ms, mfu 10.59%
# step 3250: train loss 0.9415, val loss 1.4715
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3250: loss 1.0493, time 9881.25ms, mfu 9.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3260: loss 1.0426, time 45.38ms, mfu 9.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3270: loss 1.0733, time 45.26ms, mfu 9.75%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3280: loss 1.0527, time 45.16ms, mfu 9.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3290: loss 1.0732, time 44.82ms, mfu 9.94%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3300: loss 1.0449, time 45.12ms, mfu 10.01%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3310: loss 1.0419, time 45.08ms, mfu 10.08%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3320: loss 1.0637, time 48.01ms, mfu 10.08%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3330: loss 1.0691, time 45.78ms, mfu 10.12%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3340: loss 1.0457, time 44.71ms, mfu 10.19%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3350: loss 1.0478, time 44.84ms, mfu 10.25%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3360: loss 1.0707, time 44.55ms, mfu 10.31%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3370: loss 1.0449, time 45.07ms, mfu 10.35%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3380: loss 1.0269, time 44.76ms, mfu 10.39%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3390: loss 1.0275, time 44.74ms, mfu 10.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3400: loss 1.0192, time 44.80ms, mfu 10.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3410: loss 1.0339, time 44.74ms, mfu 10.49%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3420: loss 1.0296, time 44.84ms, mfu 10.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3430: loss 1.0520, time 44.63ms, mfu 10.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3440: loss 1.0611, time 44.70ms, mfu 10.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3450: loss 1.0301, time 44.70ms, mfu 10.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3460: loss 1.0345, time 44.70ms, mfu 10.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3470: loss 1.0511, time 44.68ms, mfu 10.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3480: loss 1.0563, time 45.77ms, mfu 10.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3490: loss 1.0469, time 44.60ms, mfu 10.64%
# step 3500: train loss 0.9122, val loss 1.4834
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3500: loss 1.0412, time 9929.32ms, mfu 9.59%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3510: loss 1.0495, time 45.08ms, mfu 9.70%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3520: loss 1.0178, time 44.90ms, mfu 9.80%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3530: loss 1.0226, time 44.76ms, mfu 9.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3540: loss 1.0378, time 44.78ms, mfu 9.99%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3550: loss 1.0473, time 45.04ms, mfu 10.06%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3560: loss 1.0076, time 44.88ms, mfu 10.13%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3570: loss 1.0339, time 44.88ms, mfu 10.19%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3580: loss 1.0377, time 44.81ms, mfu 10.25%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3590: loss 1.0303, time 44.82ms, mfu 10.30%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3600: loss 1.0221, time 44.68ms, mfu 10.35%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3610: loss 1.0411, time 44.41ms, mfu 10.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3620: loss 1.0485, time 44.58ms, mfu 10.44%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3630: loss 1.0359, time 44.73ms, mfu 10.48%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3640: loss 1.0196, time 44.93ms, mfu 10.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3650: loss 1.0222, time 47.63ms, mfu 10.47%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3660: loss 1.0110, time 45.09ms, mfu 10.49%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3670: loss 0.9938, time 44.96ms, mfu 10.51%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3680: loss 1.0245, time 45.09ms, mfu 10.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3690: loss 1.0225, time 44.81ms, mfu 10.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3700: loss 0.9893, time 45.14ms, mfu 10.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3710: loss 1.0034, time 45.02ms, mfu 10.58%
# ...
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3890: loss 0.9994, time 44.70ms, mfu 10.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3900: loss 0.9917, time 44.82ms, mfu 10.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3910: loss 0.9891, time 44.81ms, mfu 10.49%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3920: loss 1.0006, time 44.68ms, mfu 10.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3930: loss 1.0089, time 45.59ms, mfu 10.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3940: loss 0.9826, time 45.30ms, mfu 10.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3950: loss 1.0063, time 44.87ms, mfu 10.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3960: loss 0.9953, time 44.71ms, mfu 10.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3970: loss 0.9837, time 44.47ms, mfu 10.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3980: loss 0.9679, time 44.62ms, mfu 10.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3990: loss 0.9921, time 44.89ms, mfu 10.64%
# step 4000: train loss 0.8599, val loss 1.5151
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4000: loss 1.0203, time 9843.90ms, mfu 9.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4010: loss 1.0090, time 44.56ms, mfu 9.71%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4020: loss 0.9592, time 44.38ms, mfu 9.82%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4030: loss 0.9682, time 44.40ms, mfu 9.93%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4040: loss 0.9766, time 44.02ms, mfu 10.03%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4050: loss 0.9924, time 44.18ms, mfu 10.12%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4060: loss 0.9710, time 45.17ms, mfu 10.18%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4070: loss 0.9808, time 44.62ms, mfu 10.24%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4080: loss 0.9722, time 44.85ms, mfu 10.29%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4090: loss 1.0072, time 44.72ms, mfu 10.34%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4100: loss 0.9946, time 44.50ms, mfu 10.39%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4110: loss 1.0030, time 44.33ms, mfu 10.44%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4120: loss 0.9720, time 44.54ms, mfu 10.48%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4130: loss 0.9875, time 44.52ms, mfu 10.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4140: loss 0.9798, time 45.49ms, mfu 10.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4150: loss 1.0190, time 44.81ms, mfu 10.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4160: loss 0.9842, time 47.75ms, mfu 10.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4170: loss 0.9866, time 45.26ms, mfu 10.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4180: loss 0.9837, time 45.37ms, mfu 10.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4190: loss 0.9927, time 45.22ms, mfu 10.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4200: loss 0.9800, time 44.88ms, mfu 10.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4210: loss 0.9947, time 45.26ms, mfu 10.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4220: loss 0.9625, time 45.39ms, mfu 10.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4230: loss 0.9587, time 45.09ms, mfu 10.59%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4240: loss 0.9750, time 45.07ms, mfu 10.60%
# step 4250: train loss 0.8389, val loss 1.5218
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4250: loss 0.9897, time 9807.75ms, mfu 9.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4260: loss 0.9794, time 44.57ms, mfu 9.68%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4270: loss 0.9835, time 44.27ms, mfu 9.80%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4280: loss 0.9908, time 45.56ms, mfu 9.88%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4290: loss 0.9947, time 45.61ms, mfu 9.95%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4300: loss 0.9662, time 44.55ms, mfu 10.04%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4310: loss 0.9926, time 45.34ms, mfu 10.10%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4320: loss 0.9644, time 44.50ms, mfu 10.17%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4330: loss 0.9808, time 44.76ms, mfu 10.23%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4340: loss 0.9843, time 44.63ms, mfu 10.29%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4350: loss 0.9755, time 44.55ms, mfu 10.34%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4360: loss 0.9845, time 44.72ms, mfu 10.39%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4370: loss 0.9669, time 44.60ms, mfu 10.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4380: loss 0.9858, time 44.53ms, mfu 10.47%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4390: loss 0.9597, time 44.54ms, mfu 10.51%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4400: loss 0.9663, time 47.04ms, mfu 10.48%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4410: loss 0.9664, time 46.95ms, mfu 10.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4420: loss 0.9848, time 44.92ms, mfu 10.49%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4430: loss 0.9808, time 44.09ms, mfu 10.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4440: loss 0.9687, time 44.19ms, mfu 10.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4450: loss 0.9475, time 44.21ms, mfu 10.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4460: loss 0.9870, time 44.52ms, mfu 10.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4470: loss 0.9753, time 44.15ms, mfu 10.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4480: loss 0.9928, time 44.39ms, mfu 10.68%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4490: loss 0.9706, time 44.22ms, mfu 10.70%
# step 4500: train loss 0.8215, val loss 1.5231
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4500: loss 0.9476, time 9837.22ms, mfu 9.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4510: loss 0.9596, time 45.57ms, mfu 9.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4520: loss 0.9497, time 44.61ms, mfu 9.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4530: loss 0.9567, time 44.82ms, mfu 9.93%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4540: loss 0.9800, time 44.76ms, mfu 10.02%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4550: loss 0.9530, time 44.78ms, mfu 10.09%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4560: loss 0.9384, time 44.76ms, mfu 10.16%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4570: loss 0.9460, time 44.70ms, mfu 10.23%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4580: loss 0.9678, time 44.68ms, mfu 10.28%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4590: loss 0.9352, time 44.65ms, mfu 10.34%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4600: loss 0.9759, time 44.47ms, mfu 10.39%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4610: loss 0.9710, time 44.66ms, mfu 10.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4620: loss 0.9672, time 44.73ms, mfu 10.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4630: loss 0.9569, time 44.66ms, mfu 10.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4640: loss 0.9481, time 44.56ms, mfu 10.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4650: loss 0.9334, time 44.64ms, mfu 10.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4660: loss 0.9763, time 44.65ms, mfu 10.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4670: loss 0.9467, time 45.03ms, mfu 10.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4680: loss 0.9915, time 44.28ms, mfu 10.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4690: loss 0.9444, time 44.14ms, mfu 10.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4700: loss 0.9371, time 44.28ms, mfu 10.68%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4710: loss 0.9779, time 44.14ms, mfu 10.71%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4720: loss 0.9693, time 44.19ms, mfu 10.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4730: loss 0.9840, time 47.47ms, mfu 10.67%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4740: loss 0.9520, time 45.39ms, mfu 10.67%
# step 4750: train loss 0.8068, val loss 1.5312
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4750: loss 0.9641, time 9737.63ms, mfu 9.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4760: loss 0.9489, time 44.25ms, mfu 9.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4770: loss 0.9456, time 44.14ms, mfu 9.85%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4780: loss 0.9489, time 44.43ms, mfu 9.96%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4790: loss 0.9300, time 44.37ms, mfu 10.05%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4800: loss 0.9556, time 44.13ms, mfu 10.14%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4810: loss 0.9651, time 44.83ms, mfu 10.20%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4820: loss 0.9344, time 47.08ms, mfu 10.20%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4830: loss 0.9527, time 45.61ms, mfu 10.24%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4840: loss 0.9698, time 44.72ms, mfu 10.30%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4850: loss 0.9545, time 44.61ms, mfu 10.35%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4860: loss 0.9630, time 44.93ms, mfu 10.39%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4870: loss 0.9487, time 44.97ms, mfu 10.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4880: loss 0.9565, time 44.83ms, mfu 10.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4890: loss 0.9351, time 44.81ms, mfu 10.49%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4900: loss 0.9384, time 44.89ms, mfu 10.51%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4910: loss 0.9237, time 44.91ms, mfu 10.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4920: loss 0.9523, time 44.52ms, mfu 10.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4930: loss 0.9402, time 44.41ms, mfu 10.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4940: loss 0.9449, time 47.52ms, mfu 10.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4950: loss 0.9553, time 46.17ms, mfu 10.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4960: loss 0.9465, time 44.66ms, mfu 10.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4970: loss 0.9466, time 44.53ms, mfu 10.59%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4980: loss 0.9481, time 46.26ms, mfu 10.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4990: loss 0.9425, time 44.56ms, mfu 10.60%
# step 5000: train loss 0.7945, val loss 1.5506
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 5000: loss 0.9401, time 9749.87ms, mfu 9.55%
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# VBox(children=(Label(value='0.159 MB of 0.252 MB uploaded\r'), FloatProgress(value=0.6303161990998187, max=1.0…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iter</td><td>▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>lr</td><td>▁████▇▇▆▆▅▅▄▄▃▃▃▂▂▂▂▂</td></tr><tr><td>mfu</td><td>▁████████████████████</td></tr><tr><td>test/loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>█▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iter</td><td>5000</td></tr><tr><td>lr</td><td>0.0001</td></tr><tr><td>mfu</td><td>10.60284</td></tr><tr><td>test/loss</td><td>1.62369</td></tr><tr><td>train/loss</td><td>0.79455</td></tr><tr><td>val/loss</td><td>1.55058</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">AbstractTransformerLM</strong> at: <a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/spj237be' target="_blank">https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/spj237be</a><br/>Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20240118_181223-spj237be/logs</code>
# DONE.

# %%
prompt = 'Romeo'

char_to_idx = meta_data['stoi']
idx_to_char = meta_data['itos']
prompt_idx = torch.from_numpy(np.array([char_to_idx[c] for c in prompt])).unsqueeze(0).to('cuda')
sample_gen = model.generate(prompt_idx, max_new_tokens=1000, temperature=1.0, top_k=None)[0]
sample_gen = ''.join([idx_to_char[idx] for idx in np.array(sample_gen.cpu())])
print(sample_gen)
# Out:
# Romeo,--
#
# KING HENRY VI:
# He was for him to be found that Richard now.
#
# DERBY:
# My lord, I proud away not: ount take no letters
# Twixt thy gracious lord begin. Who's the matter,
# With some gone aloof?
#
# BUCKINGHAM:
# Say brought your not, sir?
#
# TRANCIO:
# What scorn you do very good note:
# My lord, I am content my duteous bildhs away.
#
# BAGOT:
# I have subjects beats but next thy father,
# Apparender thee: Take honour in our senate.
#
# PAULINA:
# This way be thy nose physician, if he be
# To be a bad-: Tradam? his any conduction,
# His rason was not a parturer,
# Or hang denied at the king! Sir Jethop's off,
# Should be halp there, says Tybalt, Queen Nedalus,
# Shore the king.
#
# QUEEN MARGARET:
# Oh shall forge you ashame to Richmond!
#
# KING HENRY VI:
# For welcome, welcomemes thee from the key-roof
# Lord MarsS ay, and fly will not this hoofest
# Rest, and let he go forth his wither's groans?
#
# QUEEN MARGARET:
# True executions of men:
# Ah, with all horses of conceit so evide.
#
# KING HENRY VI:
# Defusions, worship thee, and what subje

# %% [markdown]
# ## Abstract Transformer Model (Relational Symbolic Attention)

# %%
model_args = dict(
    vocab_size=vocab_size, d_model=384, n_layers=6, n_heads_enc=4, n_heads_abs=2, dff=None,
    symbol_retrieval='rel_sym_attn', symbol_retrieval_kwargs=dict(
        model_dim=384, rel_n_heads=4, symbolic_attn_n_heads=4,
        num_symbols=20, nbhd_delta=5, causal_nbhd=True, include_self=False,
        normalize_rels=True), # FIXME make names consistent: d_model, model_dim
    dropout_rate=0.2, activation='relu', norm_first=True, max_block_size=256, bias=True)
model = abstracttransformer_lm = AbstractTransformerLM(**model_args).to(device)

# %%
torchinfo.summary(model, input_data=torch.randint(0, 10, size=(1,256)), device='cuda')
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# AbstractTransformerLM                                   [1, 1, 65]                --
# ├─ModuleDict: 1-1                                       --                        --
# │    └─Embedding: 2-1                                   [1, 256, 384]             24,960
# │    └─Embedding: 2-2                                   [256, 384]                98,304
# │    └─ModuleList: 2-3                                  --                        --
# │    │    └─AbstractEncoderBlock: 3-1                   [1, 256, 384]             2,684,928
# │    │    └─AbstractEncoderBlock: 3-14                  --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-3                   --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-4                   [1, 256, 384]             2,684,928
# │    │    └─AbstractEncoderBlock: 3-14                  --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-6                   --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-7                   [1, 256, 384]             2,684,928
# │    │    └─AbstractEncoderBlock: 3-14                  --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-9                   --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-10                  [1, 256, 384]             2,684,928
# │    │    └─AbstractEncoderBlock: 3-14                  --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-12                  --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-13                  [1, 256, 384]             2,684,928
# │    │    └─AbstractEncoderBlock: 3-14                  --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-15                  --                        (recursive)
# │    │    └─AbstractEncoderBlock: 3-16                  [1, 256, 384]             2,684,928
# │    └─Linear: 2-4                                      [1, 1, 65]                25,025
# =========================================================================================================
# Total params: 27,810,881
# Trainable params: 27,810,881
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 35.02
# =========================================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 53.48
# Params size (MB): 30.79
# Estimated Total Size (MB): 84.27
# =========================================================================================================

# %%
# torchinfo overcounts # of params... something to do with symbolic attention shared across layers
# this is the correct number (similar to TransformerLM)

num_params = model.get_num_params() #sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'# of params {num_params:,}')
# Out:
# # of params 13,824,833

# %%
# TODO: can we implement in a way that torchinfo can understand? i.e., without "recursive" and overcounting

# %% [markdown]
# ### Training

# %%
# grad scaler
scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16'))
# optimizer
optimizer = configure_optimizers(model, weight_decay, learning_rate, (beta1, beta2), device_type=device)
# Out:
# num decayed parameter tensors: 45, with 13,884,672 parameters
# num non-decayed parameter tensors: 65, with 38,465 parameters
# using fused AdamW: True

# %%
def get_lr(it):
    # 1) linear warmup for warmup_iters steps
    if it < warmup_iters:
        return learning_rate * it / warmup_iters
    # 2) if it > lr_decay_iters, return min learning rate
    if it > lr_decay_iters:
        return min_lr
    # 3) in between, use cosine decay down to min learning rate
    decay_ratio = (it - warmup_iters) / (lr_decay_iters - warmup_iters)
    assert 0 <= decay_ratio <= 1
    coeff = 0.5 * (1.0 + math.cos(math.pi * decay_ratio)) # coeff ranges 0..1
    return min_lr + coeff * (learning_rate - min_lr)

# %%
@torch.no_grad()
def eval_model(model, ctx=None):

    ctx = nullcontext() if ctx is None else ctx
    out = {}
    model.eval()
    for split in ['train', 'val', 'test']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            with ctx:
                logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[f'{split}/loss'] = losses.mean()
    model.train()
    return out

# %%
train_kwargs = dict(
    model=model, get_batch=get_batch, batch_size=batch_size, max_iters=max_iters,
    optimizer=optimizer, scaler=scaler, get_lr=get_lr, eval_model=eval_model,
    compile=True, grad_clip=0, gradient_accumulation_steps=gradient_accumulation_steps,
    eval_main_metric='val/loss', eval_interval=eval_interval, always_save_checkpoint=always_save_checkpoint, out_dir=out_dir,
    log_interval=10, wandb_log=True, wandb_init_kwargs=dict(project=wandb_project, name='AbstractTransformerLM (Relational Symbolic Attn)'), 
    ckpt_dict=dict(model_args=model_args), track_mfu=True,
    master_process=True, ddp=False, device_type='cuda')

# %%
train_model(**train_kwargs)
# Out:
# Tracking run with wandb version 0.16.2
# Run data is saved locally in <code>/gpfs/gibbs/project/lafferty/ma2393/abstract_transformer/experiments/wandb/run-20240118_184804-2v1kqg5t</code>
# Syncing run <strong><a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/2v1kqg5t' target="_blank">AbstractTransformerLM</a></strong> to <a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char' target="_blank">https://wandb.ai/awni00/abstract_transformer--shakespeare_char</a>
#  View run at <a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/2v1kqg5t' target="_blank">https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/2v1kqg5t</a>
# compiling model... done compiling.
# starting training loop...
# step 0: train loss 4.5255, val loss 4.5268
# iter 0: loss 4.5382, time 62455.47ms, mfu -100.00%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 10: loss 3.4265, time 71.24ms, mfu 6.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 20: loss 3.0166, time 70.68ms, mfu 6.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 30: loss 2.7976, time 70.80ms, mfu 6.91%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 40: loss 2.6931, time 71.38ms, mfu 6.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 50: loss 2.5840, time 70.93ms, mfu 6.91%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 60: loss 2.5717, time 71.03ms, mfu 6.91%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 70: loss 2.5228, time 70.62ms, mfu 6.91%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 80: loss 2.5126, time 70.75ms, mfu 6.92%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 90: loss 2.4902, time 70.59ms, mfu 6.92%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 100: loss 2.4921, time 70.72ms, mfu 6.92%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 110: loss 2.4890, time 71.50ms, mfu 6.92%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 120: loss 2.4800, time 70.95ms, mfu 6.92%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 130: loss 2.4467, time 71.26ms, mfu 6.92%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 140: loss 2.4020, time 70.77ms, mfu 6.92%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 150: loss 2.3805, time 70.72ms, mfu 6.92%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 160: loss 2.3588, time 70.91ms, mfu 6.92%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 170: loss 2.3046, time 70.69ms, mfu 6.93%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 180: loss 2.2712, time 70.29ms, mfu 6.93%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 190: loss 2.2110, time 70.42ms, mfu 6.94%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 200: loss 2.1759, time 70.64ms, mfu 6.94%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 210: loss 2.1500, time 70.28ms, mfu 6.94%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 220: loss 2.0756, time 70.42ms, mfu 6.95%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 230: loss 2.0596, time 70.33ms, mfu 6.95%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 240: loss 2.0081, time 70.34ms, mfu 6.95%
# step 250: train loss 1.9152, val loss 2.0111
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 250: loss 1.9870, time 11657.31ms, mfu 6.26%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 260: loss 1.9378, time 70.32ms, mfu 6.34%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 270: loss 1.9313, time 70.27ms, mfu 6.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 280: loss 1.9060, time 70.42ms, mfu 6.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 290: loss 1.8970, time 70.34ms, mfu 6.51%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 300: loss 1.8465, time 70.38ms, mfu 6.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 310: loss 1.8328, time 71.73ms, mfu 6.59%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 320: loss 1.8220, time 70.33ms, mfu 6.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 330: loss 1.8013, time 70.21ms, mfu 6.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 340: loss 1.7781, time 70.40ms, mfu 6.70%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 350: loss 1.7557, time 70.51ms, mfu 6.72%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 360: loss 1.7467, time 70.19ms, mfu 6.75%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 370: loss 1.7555, time 70.32ms, mfu 6.77%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 380: loss 1.6937, time 70.23ms, mfu 6.80%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 390: loss 1.6972, time 70.28ms, mfu 6.82%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 400: loss 1.6577, time 70.46ms, mfu 6.83%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 410: loss 1.6703, time 70.20ms, mfu 6.85%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 420: loss 1.6940, time 70.45ms, mfu 6.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 430: loss 1.6873, time 70.31ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 440: loss 1.6432, time 70.58ms, mfu 6.88%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 450: loss 1.6395, time 70.29ms, mfu 6.89%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 460: loss 1.6390, time 70.37ms, mfu 6.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 470: loss 1.5862, time 70.52ms, mfu 6.91%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 480: loss 1.5974, time 70.34ms, mfu 6.92%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 490: loss 1.5760, time 70.49ms, mfu 6.92%
# step 500: train loss 1.5216, val loss 1.7115
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 500: loss 1.5890, time 11591.82ms, mfu 6.23%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 510: loss 1.5789, time 70.69ms, mfu 6.31%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 520: loss 1.5759, time 70.29ms, mfu 6.37%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 530: loss 1.5783, time 70.91ms, mfu 6.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 540: loss 1.5974, time 70.43ms, mfu 6.48%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 550: loss 1.5294, time 70.71ms, mfu 6.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 560: loss 1.5430, time 71.09ms, mfu 6.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 570: loss 1.5511, time 70.29ms, mfu 6.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 580: loss 1.5328, time 70.62ms, mfu 6.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 590: loss 1.5265, time 70.39ms, mfu 6.68%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 600: loss 1.5346, time 70.52ms, mfu 6.71%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 610: loss 1.5328, time 72.14ms, mfu 6.72%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 620: loss 1.5365, time 70.49ms, mfu 6.74%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 630: loss 1.4904, time 70.41ms, mfu 6.77%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 640: loss 1.4938, time 70.47ms, mfu 6.79%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 650: loss 1.4943, time 70.81ms, mfu 6.80%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 660: loss 1.4823, time 71.06ms, mfu 6.81%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 670: loss 1.4672, time 70.52ms, mfu 6.83%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 680: loss 1.4891, time 70.45ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 690: loss 1.4914, time 70.44ms, mfu 6.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 700: loss 1.4703, time 70.40ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 710: loss 1.4469, time 70.36ms, mfu 6.88%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 720: loss 1.4934, time 70.66ms, mfu 6.89%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 730: loss 1.4620, time 70.44ms, mfu 6.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 740: loss 1.4483, time 70.48ms, mfu 6.90%
# step 750: train loss 1.3832, val loss 1.5784
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 750: loss 1.4539, time 11623.78ms, mfu 6.22%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 760: loss 1.4388, time 70.38ms, mfu 6.29%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 770: loss 1.4511, time 81.47ms, mfu 6.27%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 780: loss 1.4712, time 70.39ms, mfu 6.34%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 790: loss 1.4241, time 70.56ms, mfu 6.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 800: loss 1.4467, time 70.68ms, mfu 6.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 810: loss 1.4567, time 71.46ms, mfu 6.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 820: loss 1.4251, time 70.44ms, mfu 6.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 830: loss 1.4670, time 70.40ms, mfu 6.59%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 840: loss 1.4290, time 70.36ms, mfu 6.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 850: loss 1.4456, time 70.56ms, mfu 6.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 860: loss 1.4094, time 70.76ms, mfu 6.69%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 870: loss 1.3607, time 70.77ms, mfu 6.72%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 880: loss 1.3734, time 70.24ms, mfu 6.74%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 890: loss 1.3916, time 70.45ms, mfu 6.77%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 900: loss 1.3816, time 70.46ms, mfu 6.79%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 910: loss 1.3904, time 70.32ms, mfu 6.81%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 920: loss 1.3963, time 70.69ms, mfu 6.82%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 930: loss 1.3826, time 70.49ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 940: loss 1.3632, time 71.91ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 950: loss 1.3979, time 72.78ms, mfu 6.83%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 960: loss 1.3424, time 72.08ms, mfu 6.83%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 970: loss 1.3872, time 71.02ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 980: loss 1.3978, time 70.59ms, mfu 6.85%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 990: loss 1.3904, time 70.44ms, mfu 6.86%
# step 1000: train loss 1.3094, val loss 1.5386
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1000: loss 1.3695, time 11607.12ms, mfu 6.18%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1010: loss 1.3564, time 70.69ms, mfu 6.26%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1020: loss 1.3761, time 70.59ms, mfu 6.33%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1030: loss 1.3569, time 70.44ms, mfu 6.39%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1040: loss 1.3299, time 71.22ms, mfu 6.44%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1050: loss 1.3538, time 70.62ms, mfu 6.49%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1060: loss 1.3447, time 70.56ms, mfu 6.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1070: loss 1.3646, time 70.52ms, mfu 6.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1080: loss 1.3496, time 71.97ms, mfu 6.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1090: loss 1.3506, time 70.56ms, mfu 6.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1100: loss 1.3132, time 70.43ms, mfu 6.68%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1110: loss 1.3625, time 70.67ms, mfu 6.70%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1120: loss 1.3347, time 70.41ms, mfu 6.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1130: loss 1.3343, time 70.51ms, mfu 6.76%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1140: loss 1.3486, time 70.39ms, mfu 6.78%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1150: loss 1.3792, time 70.42ms, mfu 6.80%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1160: loss 1.3360, time 70.54ms, mfu 6.81%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1170: loss 1.3030, time 70.46ms, mfu 6.83%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1180: loss 1.3444, time 70.60ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1190: loss 1.3337, time 70.40ms, mfu 6.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1200: loss 1.3176, time 70.40ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1210: loss 1.3071, time 70.43ms, mfu 6.88%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1220: loss 1.3393, time 70.35ms, mfu 6.89%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1230: loss 1.3168, time 70.62ms, mfu 6.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1240: loss 1.3130, time 70.40ms, mfu 6.91%
# step 1250: train loss 1.2423, val loss 1.5012
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1250: loss 1.2987, time 11606.17ms, mfu 6.22%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1260: loss 1.3016, time 70.48ms, mfu 6.29%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1270: loss 1.2958, time 70.62ms, mfu 6.36%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1280: loss 1.3075, time 72.28ms, mfu 6.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1290: loss 1.3232, time 70.60ms, mfu 6.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1300: loss 1.3125, time 70.94ms, mfu 6.51%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1310: loss 1.2962, time 70.80ms, mfu 6.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1320: loss 1.2994, time 70.57ms, mfu 6.59%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1330: loss 1.2883, time 70.47ms, mfu 6.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1340: loss 1.2849, time 70.37ms, mfu 6.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1350: loss 1.2839, time 70.32ms, mfu 6.70%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1360: loss 1.3143, time 70.82ms, mfu 6.72%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1370: loss 1.2934, time 70.43ms, mfu 6.75%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1380: loss 1.3194, time 70.28ms, mfu 6.77%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1390: loss 1.3201, time 70.35ms, mfu 6.79%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1400: loss 1.2906, time 70.20ms, mfu 6.81%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1410: loss 1.2700, time 70.43ms, mfu 6.83%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1420: loss 1.3235, time 70.47ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1430: loss 1.2752, time 70.65ms, mfu 6.85%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1440: loss 1.2827, time 70.34ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1450: loss 1.2516, time 70.83ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1460: loss 1.3082, time 70.31ms, mfu 6.89%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1470: loss 1.2505, time 70.42ms, mfu 6.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1480: loss 1.2784, time 70.60ms, mfu 6.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1490: loss 1.2953, time 70.98ms, mfu 6.90%
# step 1500: train loss 1.1982, val loss 1.5025
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1500: loss 1.2885, time 11420.42ms, mfu 6.22%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1510: loss 1.3114, time 70.30ms, mfu 6.29%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1520: loss 1.2674, time 70.31ms, mfu 6.36%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1530: loss 1.2775, time 70.72ms, mfu 6.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1540: loss 1.2434, time 70.25ms, mfu 6.48%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1550: loss 1.2618, time 70.34ms, mfu 6.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1560: loss 1.2752, time 70.40ms, mfu 6.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1570: loss 1.2649, time 70.39ms, mfu 6.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1580: loss 1.2687, time 70.83ms, mfu 6.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1590: loss 1.2549, time 70.38ms, mfu 6.68%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1600: loss 1.2438, time 70.91ms, mfu 6.71%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1610: loss 1.2541, time 71.47ms, mfu 6.72%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1620: loss 1.2754, time 70.74ms, mfu 6.75%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1630: loss 1.2493, time 70.63ms, mfu 6.77%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1640: loss 1.2764, time 70.58ms, mfu 6.79%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1650: loss 1.2117, time 70.73ms, mfu 6.80%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1660: loss 1.2503, time 70.44ms, mfu 6.82%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1670: loss 1.2269, time 70.72ms, mfu 6.83%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1680: loss 1.2574, time 70.67ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1690: loss 1.2242, time 70.55ms, mfu 6.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1700: loss 1.2410, time 72.25ms, mfu 6.85%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1710: loss 1.2177, time 70.68ms, mfu 6.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1720: loss 1.2603, time 70.73ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1730: loss 1.2591, time 70.58ms, mfu 6.88%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1740: loss 1.2309, time 70.83ms, mfu 6.88%
# step 1750: train loss 1.1539, val loss 1.4884
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1750: loss 1.2183, time 11665.71ms, mfu 6.20%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1760: loss 1.2126, time 70.67ms, mfu 6.28%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1770: loss 1.2241, time 70.70ms, mfu 6.34%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1780: loss 1.2099, time 70.60ms, mfu 6.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1790: loss 1.2449, time 70.79ms, mfu 6.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1800: loss 1.2270, time 70.72ms, mfu 6.51%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1810: loss 1.2389, time 70.59ms, mfu 6.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1820: loss 1.2250, time 70.81ms, mfu 6.59%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1830: loss 1.2376, time 70.62ms, mfu 6.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1840: loss 1.2135, time 70.89ms, mfu 6.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1850: loss 1.1888, time 70.70ms, mfu 6.69%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1860: loss 1.2105, time 70.80ms, mfu 6.71%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1870: loss 1.2203, time 70.60ms, mfu 6.74%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1880: loss 1.2258, time 70.65ms, mfu 6.76%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1890: loss 1.2164, time 70.77ms, mfu 6.78%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1900: loss 1.2007, time 70.62ms, mfu 6.80%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1910: loss 1.2175, time 70.79ms, mfu 6.81%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1920: loss 1.2275, time 70.65ms, mfu 6.82%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1930: loss 1.2353, time 70.72ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1940: loss 1.1954, time 70.54ms, mfu 6.85%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1950: loss 1.2221, time 70.59ms, mfu 6.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1960: loss 1.2232, time 70.83ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1970: loss 1.2179, time 72.18ms, mfu 6.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1980: loss 1.2162, time 71.12ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 1990: loss 1.1857, time 70.85ms, mfu 6.87%
# step 2000: train loss 1.1155, val loss 1.4671
# saving checkpoint to ../out/out-shakespeare-char
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2000: loss 1.2132, time 11695.56ms, mfu 6.19%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2010: loss 1.1941, time 70.69ms, mfu 6.27%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2020: loss 1.1904, time 70.77ms, mfu 6.33%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2030: loss 1.1614, time 70.69ms, mfu 6.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2040: loss 1.2199, time 70.59ms, mfu 6.45%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2050: loss 1.1706, time 70.86ms, mfu 6.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2060: loss 1.2021, time 70.46ms, mfu 6.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2070: loss 1.1841, time 70.55ms, mfu 6.59%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2080: loss 1.2042, time 70.81ms, mfu 6.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2090: loss 1.1735, time 70.92ms, mfu 6.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2100: loss 1.1589, time 70.63ms, mfu 6.68%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2110: loss 1.1718, time 70.51ms, mfu 6.71%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2120: loss 1.1840, time 70.64ms, mfu 6.74%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2130: loss 1.1802, time 70.85ms, mfu 6.76%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2140: loss 1.1998, time 70.64ms, mfu 6.78%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2150: loss 1.1826, time 71.25ms, mfu 6.79%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2160: loss 1.1523, time 70.65ms, mfu 6.81%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2170: loss 1.1785, time 70.88ms, mfu 6.82%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2180: loss 1.1553, time 70.68ms, mfu 6.83%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2190: loss 1.1875, time 70.81ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2200: loss 1.1874, time 70.56ms, mfu 6.85%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2210: loss 1.1376, time 70.65ms, mfu 6.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2220: loss 1.1654, time 70.81ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2230: loss 1.1781, time 70.67ms, mfu 6.88%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2240: loss 1.1627, time 71.82ms, mfu 6.88%
# step 2250: train loss 1.0801, val loss 1.4797
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2250: loss 1.1740, time 11483.89ms, mfu 6.19%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2260: loss 1.1391, time 70.74ms, mfu 6.27%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2270: loss 1.1887, time 70.62ms, mfu 6.34%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2280: loss 1.1711, time 70.54ms, mfu 6.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2290: loss 1.1554, time 70.63ms, mfu 6.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2300: loss 1.1066, time 70.56ms, mfu 6.51%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2310: loss 1.1494, time 70.77ms, mfu 6.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2320: loss 1.1675, time 70.47ms, mfu 6.59%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2330: loss 1.1485, time 70.62ms, mfu 6.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2340: loss 1.1448, time 70.56ms, mfu 6.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2350: loss 1.1711, time 70.56ms, mfu 6.69%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2360: loss 1.1431, time 70.83ms, mfu 6.72%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2370: loss 1.1428, time 70.89ms, mfu 6.74%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2380: loss 1.1283, time 70.87ms, mfu 6.76%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2390: loss 1.1570, time 70.54ms, mfu 6.78%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2400: loss 1.1285, time 70.90ms, mfu 6.79%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2410: loss 1.1609, time 70.57ms, mfu 6.81%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2420: loss 1.1506, time 70.58ms, mfu 6.83%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2430: loss 1.1488, time 70.81ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2440: loss 1.1432, time 71.07ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2450: loss 1.1612, time 70.69ms, mfu 6.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2460: loss 1.1316, time 70.44ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2470: loss 1.1343, time 70.92ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2480: loss 1.1572, time 70.54ms, mfu 6.88%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2490: loss 1.1396, time 70.53ms, mfu 6.89%
# step 2500: train loss 1.0440, val loss 1.4907
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2500: loss 1.1362, time 11480.57ms, mfu 6.21%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2510: loss 1.1390, time 70.63ms, mfu 6.28%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2520: loss 1.1140, time 71.08ms, mfu 6.34%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2530: loss 1.1389, time 70.77ms, mfu 6.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2540: loss 1.0996, time 70.85ms, mfu 6.46%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2550: loss 1.1303, time 70.64ms, mfu 6.51%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2560: loss 1.1596, time 70.70ms, mfu 6.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2570: loss 1.1678, time 72.03ms, mfu 6.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2580: loss 1.1219, time 70.89ms, mfu 6.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2590: loss 1.1165, time 70.60ms, mfu 6.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2600: loss 1.1217, time 70.70ms, mfu 6.68%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2610: loss 1.1281, time 70.50ms, mfu 6.71%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2620: loss 1.1424, time 70.60ms, mfu 6.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2630: loss 1.1101, time 70.73ms, mfu 6.75%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2640: loss 1.1021, time 70.89ms, mfu 6.77%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2650: loss 1.1038, time 71.09ms, mfu 6.79%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2660: loss 1.0935, time 70.57ms, mfu 6.80%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2670: loss 1.1315, time 70.64ms, mfu 6.82%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2680: loss 1.1057, time 70.60ms, mfu 6.83%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2690: loss 1.1146, time 70.51ms, mfu 6.85%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2700: loss 1.1387, time 70.65ms, mfu 6.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2710: loss 1.1070, time 70.82ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2720: loss 1.1519, time 71.21ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2730: loss 1.0843, time 70.60ms, mfu 6.88%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2740: loss 1.1230, time 70.57ms, mfu 6.89%
# step 2750: train loss 1.0086, val loss 1.4851
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2750: loss 1.1147, time 11494.57ms, mfu 6.20%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2760: loss 1.1262, time 70.67ms, mfu 6.28%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2770: loss 1.1108, time 71.23ms, mfu 6.34%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2780: loss 1.1013, time 70.60ms, mfu 6.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2790: loss 1.0944, time 71.14ms, mfu 6.45%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2800: loss 1.0947, time 70.61ms, mfu 6.50%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2810: loss 1.1037, time 70.68ms, mfu 6.55%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2820: loss 1.1316, time 70.76ms, mfu 6.59%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2830: loss 1.1004, time 70.62ms, mfu 6.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2840: loss 1.0856, time 70.85ms, mfu 6.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2850: loss 1.0868, time 70.68ms, mfu 6.68%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2860: loss 1.0966, time 70.68ms, mfu 6.71%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2870: loss 1.1138, time 70.82ms, mfu 6.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2880: loss 1.1198, time 70.97ms, mfu 6.75%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2890: loss 1.1011, time 70.45ms, mfu 6.78%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2900: loss 1.0749, time 70.68ms, mfu 6.79%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2910: loss 1.0815, time 70.86ms, mfu 6.81%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2920: loss 1.0779, time 70.44ms, mfu 6.82%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2930: loss 1.0978, time 70.82ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2940: loss 1.0805, time 70.95ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2950: loss 1.0788, time 70.64ms, mfu 6.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2960: loss 1.1098, time 70.51ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2970: loss 1.0808, time 70.83ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2980: loss 1.0693, time 70.62ms, mfu 6.88%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 2990: loss 1.0729, time 70.79ms, mfu 6.89%
# step 3000: train loss 0.9692, val loss 1.4986
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3000: loss 1.0803, time 11491.11ms, mfu 6.20%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3010: loss 1.0601, time 71.63ms, mfu 6.27%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3020: loss 1.0899, time 70.78ms, mfu 6.34%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3030: loss 1.1000, time 70.53ms, mfu 6.40%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3040: loss 1.0856, time 71.46ms, mfu 6.45%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3050: loss 1.0586, time 71.19ms, mfu 6.49%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3060: loss 1.0537, time 70.77ms, mfu 6.54%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3070: loss 1.0536, time 70.85ms, mfu 6.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3080: loss 1.0733, time 70.63ms, mfu 6.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3090: loss 1.0888, time 71.12ms, mfu 6.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3100: loss 1.0508, time 70.77ms, mfu 6.67%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3110: loss 1.0650, time 70.73ms, mfu 6.70%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3120: loss 1.0869, time 71.05ms, mfu 6.72%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3130: loss 1.0733, time 70.68ms, mfu 6.75%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3140: loss 1.0681, time 70.82ms, mfu 6.77%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3150: loss 1.0430, time 70.71ms, mfu 6.78%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3160: loss 1.0725, time 70.67ms, mfu 6.80%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3170: loss 1.0475, time 70.48ms, mfu 6.82%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3180: loss 1.0271, time 71.01ms, mfu 6.83%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3190: loss 1.0497, time 72.08ms, mfu 6.83%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3200: loss 1.0644, time 70.44ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3210: loss 1.0532, time 70.55ms, mfu 6.85%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3220: loss 1.0583, time 70.28ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3230: loss 1.0878, time 70.83ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3240: loss 1.0695, time 70.63ms, mfu 6.88%
# step 3250: train loss 0.9403, val loss 1.5072
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3250: loss 1.0445, time 11402.90ms, mfu 6.20%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3260: loss 1.0701, time 70.59ms, mfu 6.27%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3270: loss 1.0564, time 70.44ms, mfu 6.35%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3280: loss 1.0781, time 70.29ms, mfu 6.41%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3290: loss 1.0286, time 70.43ms, mfu 6.47%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3300: loss 1.0365, time 70.34ms, mfu 6.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3310: loss 1.0577, time 70.64ms, mfu 6.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3320: loss 1.0568, time 71.43ms, mfu 6.59%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3330: loss 1.0307, time 70.38ms, mfu 6.63%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3340: loss 1.0612, time 70.29ms, mfu 6.67%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3350: loss 1.0343, time 70.26ms, mfu 6.70%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3360: loss 1.0192, time 70.42ms, mfu 6.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3370: loss 1.0522, time 70.35ms, mfu 6.75%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3380: loss 1.0378, time 70.68ms, mfu 6.77%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3390: loss 1.0465, time 70.55ms, mfu 6.79%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3400: loss 1.0548, time 70.37ms, mfu 6.81%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3410: loss 1.0513, time 70.40ms, mfu 6.83%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3420: loss 1.0463, time 70.36ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3430: loss 1.0348, time 70.67ms, mfu 6.85%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3440: loss 1.0435, time 70.39ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3450: loss 1.0388, time 70.76ms, mfu 6.88%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3460: loss 1.0230, time 70.41ms, mfu 6.89%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3470: loss 1.0314, time 70.78ms, mfu 6.89%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3480: loss 0.9913, time 70.67ms, mfu 6.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3490: loss 1.0887, time 70.39ms, mfu 6.91%
# step 3500: train loss 0.9084, val loss 1.5304
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3500: loss 1.0399, time 11397.26ms, mfu 6.22%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3510: loss 1.0183, time 71.05ms, mfu 6.29%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3520: loss 1.0464, time 70.47ms, mfu 6.36%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3530: loss 1.0554, time 70.75ms, mfu 6.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3540: loss 1.0148, time 70.37ms, mfu 6.47%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3550: loss 1.0076, time 70.69ms, mfu 6.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3560: loss 1.0285, time 70.70ms, mfu 6.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3570: loss 1.0245, time 70.63ms, mfu 6.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3580: loss 1.0259, time 70.66ms, mfu 6.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3590: loss 0.9950, time 70.31ms, mfu 6.67%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3600: loss 1.0097, time 70.29ms, mfu 6.70%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3610: loss 1.0370, time 70.35ms, mfu 6.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3620: loss 1.0344, time 70.15ms, mfu 6.76%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3630: loss 1.0390, time 70.42ms, mfu 6.78%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3640: loss 1.0261, time 70.35ms, mfu 6.80%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3650: loss 1.0298, time 70.35ms, mfu 6.82%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3660: loss 0.9927, time 70.47ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3670: loss 1.0097, time 70.75ms, mfu 6.85%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3680: loss 1.0394, time 70.58ms, mfu 6.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3690: loss 1.0131, time 70.37ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3700: loss 1.0231, time 70.80ms, mfu 6.88%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3710: loss 1.0080, time 70.20ms, mfu 6.89%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3720: loss 1.0228, time 70.28ms, mfu 6.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3730: loss 1.0014, time 70.39ms, mfu 6.91%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3740: loss 1.0376, time 70.67ms, mfu 6.91%
# ...
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3880: loss 0.9997, time 70.32ms, mfu 6.78%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3890: loss 1.0186, time 74.13ms, mfu 6.76%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3900: loss 1.0078, time 70.37ms, mfu 6.78%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3910: loss 0.9869, time 70.43ms, mfu 6.80%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3920: loss 0.9915, time 70.46ms, mfu 6.82%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3930: loss 0.9952, time 70.66ms, mfu 6.83%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3940: loss 1.0062, time 70.55ms, mfu 6.85%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3950: loss 0.9851, time 70.26ms, mfu 6.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3960: loss 0.9897, time 70.39ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3970: loss 0.9713, time 70.30ms, mfu 6.88%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3980: loss 0.9756, time 70.34ms, mfu 6.89%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 3990: loss 0.9781, time 70.48ms, mfu 6.90%
# step 4000: train loss 0.8547, val loss 1.5384
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4000: loss 0.9956, time 11393.33ms, mfu 6.22%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4010: loss 0.9884, time 70.33ms, mfu 6.29%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4020: loss 0.9797, time 70.27ms, mfu 6.36%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4030: loss 1.0112, time 70.37ms, mfu 6.43%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4040: loss 0.9782, time 70.49ms, mfu 6.48%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4050: loss 0.9902, time 70.24ms, mfu 6.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4060: loss 0.9734, time 70.19ms, mfu 6.58%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4070: loss 0.9807, time 70.33ms, mfu 6.62%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4080: loss 0.9719, time 70.32ms, mfu 6.66%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4090: loss 0.9664, time 70.66ms, mfu 6.69%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4100: loss 0.9758, time 70.26ms, mfu 6.72%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4110: loss 0.9770, time 70.85ms, mfu 6.74%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4120: loss 0.9735, time 70.35ms, mfu 6.76%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4130: loss 1.0003, time 70.59ms, mfu 6.78%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4140: loss 0.9860, time 70.33ms, mfu 6.80%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4150: loss 0.9919, time 70.40ms, mfu 6.82%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4160: loss 0.9894, time 70.55ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4170: loss 0.9681, time 70.26ms, mfu 6.85%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4180: loss 0.9868, time 70.59ms, mfu 6.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4190: loss 0.9632, time 70.61ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4200: loss 0.9657, time 70.40ms, mfu 6.88%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4210: loss 0.9885, time 70.33ms, mfu 6.89%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4220: loss 0.9896, time 71.32ms, mfu 6.89%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4230: loss 0.9912, time 70.73ms, mfu 6.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4240: loss 0.9816, time 70.33ms, mfu 6.91%
# step 4250: train loss 0.8309, val loss 1.5539
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4250: loss 0.9419, time 11398.41ms, mfu 6.22%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4260: loss 0.9970, time 70.50ms, mfu 6.30%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4270: loss 0.9482, time 70.30ms, mfu 6.36%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4280: loss 0.9559, time 70.69ms, mfu 6.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4290: loss 0.9708, time 70.32ms, mfu 6.48%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4300: loss 0.9546, time 70.42ms, mfu 6.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4310: loss 0.9681, time 70.55ms, mfu 6.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4320: loss 0.9583, time 70.28ms, mfu 6.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4330: loss 0.9712, time 70.51ms, mfu 6.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4340: loss 0.9877, time 70.45ms, mfu 6.68%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4350: loss 0.9686, time 70.98ms, mfu 6.71%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4360: loss 0.9612, time 70.41ms, mfu 6.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4370: loss 0.9670, time 70.46ms, mfu 6.76%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4380: loss 0.9614, time 70.43ms, mfu 6.78%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4390: loss 0.9931, time 70.49ms, mfu 6.80%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4400: loss 0.9566, time 70.63ms, mfu 6.81%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4410: loss 0.9801, time 70.43ms, mfu 6.83%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4420: loss 0.9603, time 70.68ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4430: loss 0.9646, time 70.43ms, mfu 6.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4440: loss 0.9477, time 70.42ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4450: loss 0.9599, time 70.96ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4460: loss 0.9694, time 70.61ms, mfu 6.88%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4470: loss 0.9617, time 70.59ms, mfu 6.89%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4480: loss 0.9411, time 70.60ms, mfu 6.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4490: loss 0.9653, time 70.42ms, mfu 6.90%
# step 4500: train loss 0.8148, val loss 1.5586
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4500: loss 0.9551, time 11419.55ms, mfu 6.22%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4510: loss 0.9611, time 70.47ms, mfu 6.29%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4520: loss 0.9765, time 70.26ms, mfu 6.36%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4530: loss 0.9649, time 70.62ms, mfu 6.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4540: loss 0.9449, time 70.28ms, mfu 6.48%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4550: loss 0.9518, time 70.76ms, mfu 6.53%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4560: loss 0.9396, time 70.44ms, mfu 6.57%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4570: loss 0.9582, time 70.42ms, mfu 6.61%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4580: loss 0.9479, time 70.59ms, mfu 6.65%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4590: loss 0.9396, time 70.33ms, mfu 6.68%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4600: loss 0.9322, time 70.88ms, mfu 6.71%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4610: loss 0.9440, time 70.50ms, mfu 6.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4620: loss 0.9625, time 70.41ms, mfu 6.76%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4630: loss 0.9434, time 70.28ms, mfu 6.78%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4640: loss 0.9463, time 70.60ms, mfu 6.80%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4650: loss 0.9481, time 70.54ms, mfu 6.81%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4660: loss 0.9607, time 70.51ms, mfu 6.83%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4670: loss 0.9570, time 70.80ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4680: loss 0.9805, time 70.35ms, mfu 6.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4690: loss 0.9636, time 70.42ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4700: loss 0.9611, time 70.58ms, mfu 6.88%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4710: loss 0.9400, time 70.59ms, mfu 6.89%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4720: loss 0.9646, time 70.83ms, mfu 6.89%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4730: loss 0.9426, time 70.43ms, mfu 6.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4740: loss 0.9430, time 70.52ms, mfu 6.91%
# step 4750: train loss 0.8008, val loss 1.5669
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4750: loss 0.9543, time 11374.40ms, mfu 6.22%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4760: loss 0.9555, time 70.51ms, mfu 6.29%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4770: loss 0.9648, time 70.80ms, mfu 6.36%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4780: loss 0.9589, time 70.76ms, mfu 6.42%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4790: loss 0.9708, time 70.61ms, mfu 6.47%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4800: loss 0.9604, time 70.54ms, mfu 6.52%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4810: loss 0.9507, time 70.79ms, mfu 6.56%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4820: loss 0.9301, time 70.52ms, mfu 6.60%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4830: loss 0.9413, time 70.60ms, mfu 6.64%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4840: loss 0.9596, time 70.62ms, mfu 6.67%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4850: loss 0.9538, time 70.51ms, mfu 6.70%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4860: loss 0.9496, time 70.39ms, mfu 6.73%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4870: loss 0.9318, time 70.50ms, mfu 6.75%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4880: loss 0.9543, time 70.37ms, mfu 6.78%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4890: loss 0.9476, time 70.45ms, mfu 6.80%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4900: loss 0.9536, time 71.89ms, mfu 6.80%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4910: loss 0.9289, time 70.69ms, mfu 6.81%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4920: loss 0.9476, time 70.66ms, mfu 6.83%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4930: loss 0.9236, time 70.37ms, mfu 6.84%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4940: loss 0.9474, time 70.51ms, mfu 6.86%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4950: loss 0.9220, time 70.30ms, mfu 6.87%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4960: loss 0.9423, time 70.54ms, mfu 6.88%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4970: loss 0.9516, time 70.60ms, mfu 6.89%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4980: loss 0.9441, time 70.33ms, mfu 6.90%
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 4990: loss 0.9328, time 70.64ms, mfu 6.90%
# step 5000: train loss 0.7895, val loss 1.5738
# WARNING: estimate_mfu implementation not checked for AbstractTransformerLM
# iter 5000: loss 0.9664, time 11407.55ms, mfu 6.22%
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# VBox(children=(Label(value='0.205 MB of 0.205 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iter</td><td>▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>lr</td><td>▁████▇▇▆▆▅▅▄▄▃▃▃▂▂▂▂▂</td></tr><tr><td>mfu</td><td>▁████████████████████</td></tr><tr><td>test/loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>█▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iter</td><td>5000</td></tr><tr><td>lr</td><td>0.0001</td></tr><tr><td>mfu</td><td>6.90287</td></tr><tr><td>test/loss</td><td>1.64222</td></tr><tr><td>train/loss</td><td>0.78946</td></tr><tr><td>val/loss</td><td>1.57376</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">AbstractTransformerLM</strong> at: <a href='https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/2v1kqg5t' target="_blank">https://wandb.ai/awni00/abstract_transformer--shakespeare_char/runs/2v1kqg5t</a><br/>Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20240118_184804-2v1kqg5t/logs</code>
# DONE.

# %%
prompt = 'Romeo'

char_to_idx = meta_data['stoi']
idx_to_char = meta_data['itos']
prompt_idx = torch.from_numpy(np.array([char_to_idx[c] for c in prompt])).unsqueeze(0).to('cuda')
sample_gen = model.generate(prompt_idx, max_new_tokens=1000, temperature=1.0, top_k=None)[0]
sample_gen = ''.join([idx_to_char[idx] for idx in np.array(sample_gen.cpu())])
print(sample_gen)
# Out:
# Romeo ran and by salk a little,
# So link'd as suggest a noble day,
# Rescued near'd with a bloody exile:
# Infection, indeed, but thy war, which stains
# You yields the fair ruled itself black tongue,
# Were it not possess together: but issues
# That most unfelt out temperance, to see it
# Of old well: there I urge betwixe,
# If the removes of one hate, by the duke, and
# Make the alms, a bow one protes of need
# By other sense; s, and thee have the groaners in
# Worse correction of Golgo substion to adder
# The drunker: and in few comfort of our weaping.
# I was the war become to kiss me with my charge
# And let it great authority?
#
# BAPTISTA:
# Will I well keep you to see the world?
#
# BENVOLIO:
# Amen not, since pass; part of rest that appeal,
# Should curses fain so fierce should by conjure
# As believing, old tyranners
# And gentle fiends out of misery, nephes,
# As main to maintains every discourse.
# Yea, are too in any croiser of
# Juliet-blood, who leaves the rest spire o' the wolf
# From thy reachery to Mantua, methinks; forswe
